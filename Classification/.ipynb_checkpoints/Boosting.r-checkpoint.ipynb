# %% [markdown]
# ### Boosting for classifying individuals

# %%
library(tidyverse)
install.packages("gbm")
library(gbm)
library(caret)
library(pROC)

install.packages("doMC")
library(doMC)

install.packages("xgboost", repos = "http://cran.us.r-project.org")
library(xgboost)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ───────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ──────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Warning message in install.packages("gbm"):
# “installation of package ‘gbm’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Loaded gbm 2.1.8
# Loading required package: lattice
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
# Type 'citation("pROC")' for a citation.
#
# Attaching package: ‘pROC’
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
#
# Warning message:
# “package ‘parallel’ is not available (for R version 3.6.1)”Warning message:
# “package ‘parallel’ is a base package, and should not be updated”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loading required package: iterators
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
#
# Attaching package: ‘xgboost’
#
# The following object is masked from ‘package:dplyr’:
#
#     slice

# %% [markdown]
# ### Real data

# %%
#data <- readRDS(snakemake@input[["input_predictions"]])
data <- readRDS("../data/ATAC_predictions_train_20_predict_80/ATAC_pred_lasso_normalized_trimmed_formatted_standardized.rds")
#data <- data[1:3000, 1:50]
head(data)
# Out:
# ERROR while rich displaying an object: Error in sprintf(wrap, header, body): 'fmt' length exceeds maximal format length 8192
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. repr_matrix_generic(obj, sprintf("\\begin{tabular}{%s}\n%%s%%s\\end{tabular}\n",
#  .     cols), "%s\\\\\n\\hline\n", "  &", " %s &", "%s", "\t%s\\\\\n",
#  .     "%s &", " %s &", escape_fun = latex_escape_vec, ...)
# 10. sprintf(wrap, header, body)
#    sample     chr10_400 chr10_40   chr10_4   chr10_401  chr10_402  chr10_403
# V1 PGDX16568P 0.7621097 -0.8032188 0.6402487 -0.8688929 -0.4792134 -0.5096581
# V2 PGDX16569P 0.7057109 -0.8227554 0.7868749 -1.0407754 -0.9284673 -0.4139074
# V3 PGDX16570P 0.4891340 -1.1448217 0.9478602 -1.0930696 -0.5115270 -0.7552269
# V4 PGDX16571P 0.6882727 -0.8585679 0.6248431 -0.8310281 -0.5335804 -0.5125528
# V5 PGDX16579P 0.5801896 -1.1674832 0.7883376 -1.0498406 -1.2475692 -0.7345196
# V6 PGDX16580P 0.6831409 -0.8712906 0.7199476 -1.1853489 -0.8520159 -0.6829992
#    chr10_404   chr10_405 chr10_406 ... chr9_39      chr9_391    chr9_392
# V1  0.02594817 0.7295906 0.7738027 ... -0.405123632  0.59187320 -0.29125018
# V2 -0.16594560 0.7765621 0.5761691 ... -0.849313481  0.39431325  0.05197526
# V3 -0.48824613 0.9537215 0.6624865 ... -0.871941533 -0.06389996 -0.22907645
# V4 -0.34185944 0.9281618 0.4768828 ... -0.005893625  0.18185487  0.32387927
# V5 -0.18778863 0.2546093 0.2920616 ... -0.067895629 -0.05197828 -0.18308631
# V6 -0.35499242 0.8598551 0.3870744 ... -0.735310376  0.36325245  0.20814984
#    chr9_393    chr9_394   chr9_395    chr9_396  chr9_397  chr9_398  chr9_399
# V1 -0.58276010  0.3792968 -0.04366948 0.9183014 0.7664238 0.9980457 -1.0572778
# V2 -0.36318168  0.1744439 -0.13785162 0.5392077 0.3942941 1.7972449 -0.3619464
# V3 -0.32470631 -0.6251958  0.17051719 0.6882020 0.1744819 1.4357406 -0.2330366
# V4  0.04577069  0.2752394  0.22750427 0.6333635 0.8413436 1.2819797  0.5629469
# V5 -0.70242368 -0.4281903 -0.06235782 1.0764914 1.1411410 0.8795170 -0.4910720
# V6 -0.50307962  0.2609116  0.53933999 1.0772367 0.6906960 1.7696570 -0.4181884

# %%
#sample_types <- read.table(snakemake@input[["input_sample_types"]], header = F, sep = " ")
sample_types <- read.table("../data/sample_types.txt", header = F, sep = " ")

colnames(sample_types) <- c("sample", "sample_type")
head(sample_types)
# Out:
#   sample      sample_type
# 1 PGDX10344P1 Gastric_cancer
# 2 PGDX10346P1 Gastric_cancer
# 3 PGDX10349P1 Gastric_cancer
# 4 PGDX10351P1 Gastric_cancer
# 5 PGDX10566P  Ovarian_Cancer
# 6 PGDX10567P  Ovarian_Cancer

# %%
dim(data)
dim(sample_types)
# Out:
# [1]   424 10304
# [1] 473   2

# %%
data <- merge(data, sample_types, by="sample")
head(data)

data <- data %>% mutate(sample_type01 = ifelse(sample_type == "Healthy", "Healthy", "Cancer"))
head(data)
# Out:
# ERROR while rich displaying an object: Error in sprintf(wrap, header, body): 'fmt' length exceeds maximal format length 8192
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. repr_matrix_generic(obj, sprintf("\\begin{tabular}{%s}\n%%s%%s\\end{tabular}\n",
#  .     cols), "%s\\\\\n\\hline\n", "  &", " %s &", "%s", "\t%s\\\\\n",
#  .     "%s &", " %s &", escape_fun = latex_escape_vec, ...)
# 10. sprintf(wrap, header, body)
#   sample      chr10_400  chr10_40   chr10_4   chr10_401  chr10_402  chr10_403
# 1 PGDX10344P1 0.28476325 -0.8212573 1.0277500 -0.7094983 -0.2327985 -0.7836319
# 2 PGDX10346P1 1.28471727 -0.8295661 1.0145149 -0.6213053 -0.8143027 -0.6479755
# 3 PGDX10349P1 0.07110482 -1.0079115 0.3347017 -1.1303365 -0.8177276 -0.9202015
# 4 PGDX10351P1 1.36298501 -1.4848879 0.4225454 -1.3192129 -0.7097136 -0.4653093
# 5 PGDX10566P  0.40245603 -1.0782760 1.2759516 -0.8646247 -0.5192562 -0.8555661
# 6 PGDX10567P  0.97825189 -0.6787169 1.0934262 -0.1749540 -0.6319351 -0.7585842
#   chr10_404   chr10_405 chr10_406 ... chr9_391    chr9_392     chr9_393
# 1  0.01979819 0.2624251 0.3128992 ... -0.34089350  0.006860094 -0.5010935
# 2 -0.06975614 0.9264024 0.4895216 ... -0.17629217 -0.421600296 -0.5810840
# 3 -0.08484151 0.5183954 2.2808829 ...  1.22409122  0.527804492 -0.1435833
# 4 -0.42147744 0.9729417 0.5944980 ...  0.43571295  0.872833915 -0.0670184
# 5 -0.22999396 0.7699482 0.4825674 ...  0.04951928  0.173364771 -0.8705736
# 6  0.22653017 0.5994301 0.6407291 ...  0.50968208 -0.241967372 -0.6951369
#   chr9_394   chr9_395    chr9_396    chr9_397   chr9_398  chr9_399
# 1 -0.2043651  0.02437101  0.57938365 -0.4136060 1.3160044 -0.26256223
# 2  0.1408379  0.21122926  1.13429106  0.8116547 0.3187471 -0.48265821
# 3  0.4967880  0.15991730  0.89522351  0.5305742 1.6767953 -0.02839009
# 4  0.7394425  0.13690205  1.29732717  0.4739056 1.4153912 -0.12217374
# 5  0.4935296 -0.17648798 -0.02395699  0.3182328 1.3930824 -0.47078676
# 6  0.2412607  0.11914801  0.07982386  0.2854560 1.7946488 -0.69550001
#   sample_type
# 1 Gastric_cancer
# 2 Gastric_cancer
# 3 Gastric_cancer
# 4 Gastric_cancer
# 5 Ovarian_Cancer
# 6 Ovarian_Cancer
# ERROR while rich displaying an object: Error in sprintf(wrap, header, body): 'fmt' length exceeds maximal format length 8192
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. repr_matrix_generic(obj, sprintf("\\begin{tabular}{%s}\n%%s%%s\\end{tabular}\n",
#  .     cols), "%s\\\\\n\\hline\n", "  &", " %s &", "%s", "\t%s\\\\\n",
#  .     "%s &", " %s &", escape_fun = latex_escape_vec, ...)
# 10. sprintf(wrap, header, body)
#   sample      chr10_400  chr10_40   chr10_4   chr10_401  chr10_402  chr10_403
# 1 PGDX10344P1 0.28476325 -0.8212573 1.0277500 -0.7094983 -0.2327985 -0.7836319
# 2 PGDX10346P1 1.28471727 -0.8295661 1.0145149 -0.6213053 -0.8143027 -0.6479755
# 3 PGDX10349P1 0.07110482 -1.0079115 0.3347017 -1.1303365 -0.8177276 -0.9202015
# 4 PGDX10351P1 1.36298501 -1.4848879 0.4225454 -1.3192129 -0.7097136 -0.4653093
# 5 PGDX10566P  0.40245603 -1.0782760 1.2759516 -0.8646247 -0.5192562 -0.8555661
# 6 PGDX10567P  0.97825189 -0.6787169 1.0934262 -0.1749540 -0.6319351 -0.7585842
#   chr10_404   chr10_405 chr10_406 ... chr9_392     chr9_393   chr9_394
# 1  0.01979819 0.2624251 0.3128992 ...  0.006860094 -0.5010935 -0.2043651
# 2 -0.06975614 0.9264024 0.4895216 ... -0.421600296 -0.5810840  0.1408379
# 3 -0.08484151 0.5183954 2.2808829 ...  0.527804492 -0.1435833  0.4967880
# 4 -0.42147744 0.9729417 0.5944980 ...  0.872833915 -0.0670184  0.7394425
# 5 -0.22999396 0.7699482 0.4825674 ...  0.173364771 -0.8705736  0.4935296
# 6  0.22653017 0.5994301 0.6407291 ... -0.241967372 -0.6951369  0.2412607
#   chr9_395    chr9_396    chr9_397   chr9_398  chr9_399    sample_type
# 1  0.02437101  0.57938365 -0.4136060 1.3160044 -0.26256223 Gastric_cancer
# 2  0.21122926  1.13429106  0.8116547 0.3187471 -0.48265821 Gastric_cancer
# 3  0.15991730  0.89522351  0.5305742 1.6767953 -0.02839009 Gastric_cancer
# 4  0.13690205  1.29732717  0.4739056 1.4153912 -0.12217374 Gastric_cancer
# 5 -0.17648798 -0.02395699  0.3182328 1.3930824 -0.47078676 Ovarian_Cancer
# 6  0.11914801  0.07982386  0.2854560 1.7946488 -0.69550001 Ovarian_Cancer
#   sample_type01
# 1 Cancer
# 2 Cancer
# 3 Cancer
# 4 Cancer
# 5 Cancer
# 6 Cancer

# %%
#data %>% filter(sample_type == "Healthy")

data <- data %>% select(-sample_type)

# %%
data <- data %>% select(-sample)
head(data)
# Out:
# ERROR while rich displaying an object: Error in sprintf(wrap, header, body): 'fmt' length exceeds maximal format length 8192
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. repr_matrix_generic(obj, sprintf("\\begin{tabular}{%s}\n%%s%%s\\end{tabular}\n",
#  .     cols), "%s\\\\\n\\hline\n", "  &", " %s &", "%s", "\t%s\\\\\n",
#  .     "%s &", " %s &", escape_fun = latex_escape_vec, ...)
# 10. sprintf(wrap, header, body)
#   chr10_400  chr10_40   chr10_4   chr10_401  chr10_402  chr10_403  chr10_404
# 1 0.28476325 -0.8212573 1.0277500 -0.7094983 -0.2327985 -0.7836319  0.01979819
# 2 1.28471727 -0.8295661 1.0145149 -0.6213053 -0.8143027 -0.6479755 -0.06975614
# 3 0.07110482 -1.0079115 0.3347017 -1.1303365 -0.8177276 -0.9202015 -0.08484151
# 4 1.36298501 -1.4848879 0.4225454 -1.3192129 -0.7097136 -0.4653093 -0.42147744
# 5 0.40245603 -1.0782760 1.2759516 -0.8646247 -0.5192562 -0.8555661 -0.22999396
# 6 0.97825189 -0.6787169 1.0934262 -0.1749540 -0.6319351 -0.7585842  0.22653017
#   chr10_405 chr10_406 chr10_407  ... chr9_391    chr9_392     chr9_393
# 1 0.2624251 0.3128992 1.45146500 ... -0.34089350  0.006860094 -0.5010935
# 2 0.9264024 0.4895216 0.04814456 ... -0.17629217 -0.421600296 -0.5810840
# 3 0.5183954 2.2808829 1.33462998 ...  1.22409122  0.527804492 -0.1435833
# 4 0.9729417 0.5944980 0.97671516 ...  0.43571295  0.872833915 -0.0670184
# 5 0.7699482 0.4825674 0.76308429 ...  0.04951928  0.173364771 -0.8705736
# 6 0.5994301 0.6407291 0.64706533 ...  0.50968208 -0.241967372 -0.6951369
#   chr9_394   chr9_395    chr9_396    chr9_397   chr9_398  chr9_399
# 1 -0.2043651  0.02437101  0.57938365 -0.4136060 1.3160044 -0.26256223
# 2  0.1408379  0.21122926  1.13429106  0.8116547 0.3187471 -0.48265821
# 3  0.4967880  0.15991730  0.89522351  0.5305742 1.6767953 -0.02839009
# 4  0.7394425  0.13690205  1.29732717  0.4739056 1.4153912 -0.12217374
# 5  0.4935296 -0.17648798 -0.02395699  0.3182328 1.3930824 -0.47078676
# 6  0.2412607  0.11914801  0.07982386  0.2854560 1.7946488 -0.69550001
#   sample_type01
# 1 Cancer
# 2 Cancer
# 3 Cancer
# 4 Cancer
# 5 Cancer
# 6 Cancer

# %%
data$sample_type01 <- as.factor(data$sample_type01)

# %%
levels(data$sample_type01)
# Out:
# [1] "Cancer"  "Healthy"

# %%
cross_validation <- function(dataset, k_inner_cv, k_outer_cv){
    
    observed  <- dataset$sample_type01
    return_tibble <- tibble(observed = observed)
    
    for (i in 1:k_outer_cv){ # repeated Cross-validation loop
    
    set.seed(i)
    cvfolds <- cut(seq_len(nrow(dataset)), breaks = k_inner_cv, labels = F)
    cvfolds <- sample(cvfolds)

    predicted <- rep(NA, nrow(dataset))
    
    for (n in 1:k_inner_cv){
        rows      <- which(cvfolds==n)
        testdata  <- dataset[rows,]
        testlabels <- testdata$sample_type01
        testdata <- testdata %>% select(-sample_type01)
        
        traindata <- dataset[-rows,]
        trainlabels <- traindata$sample_type01
        traindata <- traindata %>% select(-sample_type01)
     
        ################# Nested cross validation #######################
        set.seed(0)
        seeds <- vector(mode = "list", length = 11)
        for(i in 1:10) seeds[[i]]<- sample.int(n=1000, 18)
        #for the last model
        seeds[[11]]<-sample.int(1000, 1)

        trControl_gbm <- trainControl(method = "repeatedcv", 
                                      seeds = seeds,
                                      number = 2, 
                                      repeats = 1,
                                      classProbs = TRUE)

        gbmGrid <- expand.grid(interaction.depth = c(1, 2, 3),
                               n.trees = seq(200, 800, 200),
                               shrinkage = c(0.1, 0.2, 0.01),
                               n.minobsinnode = c(10))

        fit1 <- train(x = traindata, 
                     y = trainlabels, 
                     method = "xgbTree",
                     tuneLength = 2,
                     trControl = trControl_gbm, 
                     verbose=F, 
                     allowParallel=TRUE)
        
        message("besttune nrounds")
        message(fit1$bestTune$nrounds)
        message("besttune max_depth")
        message(fit1$bestTune$max_depth)
        message("besttune eta")
        message(fit1$bestTune$eta)
        message("besttune gamma")
        message(fit1$bestTune$gamma)
        message("besttune colsample_bytree")
        message(fit1$bestTune$colsample_bytree)
        message("besttune min_child_weight")
        message(fit1$bestTune$min_child_weight)
        message("besttune subsample")
        message(fit1$bestTune$subsample)
        #################################################################
      
        fitControl <- trainControl(classProbs = TRUE)
        fit2 <- train(x = traindata, 
                     y = trainlabels,
                     method = "xgbTree",
                     trControl = fitControl,
                     verbose = FALSE,
                     tuneGrid = data.frame(nrounds = fit1$bestTune$nrounds,
                                               max_depth = fit1$bestTune$max_depth,
                                               eta = fit1$bestTune$eta,
                                               gamma = fit1$bestTune$gamma,
                                               colsample_bytree = fit1$bestTune$colsample_bytree,
                                               min_child_weight = fit1$bestTune$min_child_weight,
                                               subsample = fit1$bestTune$subsample))
        
        tmp <- predict(fit2, newdata = testdata, type = "prob")      
        predicted[rows] <- tmp$Cancer
        
    }

    current_round_tibble <- tibble(predicted = predicted)
    return_tibble <- cbind(return_tibble, current_round_tibble)
    } # end of outer cv loop
    
    return(return_tibble)
}

# %%
results = cross_validation(data, k_inner_cv = 2, k_outer_cv = 2)
# Out:
# [20:10:49] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:10:50] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:10:53] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:10:53] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:10:57] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:10:57] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:01] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:01] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:04] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:05] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:08] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:08] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:12] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:13] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:17] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:17] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:20] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:20] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:27] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:30] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:30] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:34] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:34] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:37] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:38] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:41] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:42] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:45] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:46] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:48] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:49] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:52] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:52] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:56] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:11:56] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:00] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:00] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:04] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:04] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:08] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:08] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:12] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:12] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:17] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:17] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:20] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:20] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:24] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:27] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:27] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:30] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:31] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:34] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:34] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:37] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:38] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:41] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:42] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:46] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:12:46] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# besttune nrounds
# 50
# besttune max_depth
# 1
# besttune eta
# 0.3
# besttune gamma
# 0
# besttune colsample_bytree
# 0.8
# besttune min_child_weight
# 1
# besttune subsample
# 0.5
#     Cancer    Healthy
# 1   0.6574267 0.34257334
# 2   0.9419017 0.05809826
# 3   0.9650742 0.03492582
# 4   0.9959972 0.00400281
# 5   0.9458447 0.05415535
# 6   0.9641647 0.03583527
# 7   0.7109261 0.28907394
# 8   0.5661789 0.43382114
# 9   0.9650089 0.03499115
# 10  0.8714793 0.12852067
# 11  0.4284665 0.57153353
# 12  0.3740596 0.62594035
# 13  0.6011516 0.39884841
# 14  0.1626383 0.83736166
# 15  0.3623885 0.63761151
# 16  0.7490692 0.25093085
# 17  0.5599231 0.44007695
# 18  0.6244889 0.37551111
# 19  0.2324337 0.76756631
# 20  0.2300546 0.76994535
# 21  0.3297807 0.67021927
# 22  0.4498203 0.55017966
# 23  0.8212999 0.17870015
# 24  0.8993237 0.10067630
# 25  0.6559042 0.34409577
# 26  0.8042769 0.19572312
# 27  0.4860288 0.51397121
# 28  0.5073429 0.49265707
# 29  0.5400124 0.45998758
# 30  0.9225932 0.07740676
# ... ...       ...
# 183 0.9660117 0.033988297
# 184 0.2265097 0.773490325
# 185 0.8678825 0.132117450
# 186 0.9845443 0.015455663
# 187 0.9647919 0.035208106
# 188 0.4950288 0.504971176
# 189 0.7899009 0.210099101
# 190 0.9250320 0.074968040
# 191 0.6168991 0.383100927
# 192 0.2220861 0.777913868
# 193 0.5690169 0.430983067
# 194 0.7263848 0.273615181
# 195 0.2936258 0.706374228
# 196 0.9457039 0.054296136
# 197 0.8726733 0.127326667
# 198 0.8750647 0.124935329
# 199 0.6846873 0.315312743
# 200 0.4413379 0.558662057
# 201 0.8208529 0.179147065
# 202 0.8995827 0.100417256
# 203 0.7885591 0.211440921
# 204 0.7846391 0.215360880
# 205 0.9524668 0.047533154
# 206 0.6213959 0.378604054
# 207 0.9818147 0.018185318
# 208 0.5114594 0.488540649
# 209 0.6026368 0.397363186
# 210 0.7723442 0.227655828
# 211 0.9959394 0.004060626
# 212 0.6731637 0.326836288
#   [1] 0.65742666 0.94190174 0.96507418 0.99599719 0.94584465 0.96416473
#   [7] 0.71092606 0.56617886 0.96500885 0.87147933 0.42846647 0.37405965
#  [13] 0.60115159 0.16263834 0.36238849 0.74906915 0.55992305 0.62448889
#  [19] 0.23243369 0.23005465 0.32978073 0.44982034 0.82129985 0.89932370
#  [25] 0.65590423 0.80427688 0.48602879 0.50734293 0.54001242 0.92259324
#  [31] 0.95640761 0.37721899 0.27288872 0.02814538 0.89952737 0.19302316
#  [37] 0.97400552 0.96470457 0.99553454 0.89672464 0.96241575 0.62649518
#  [43] 0.61949849 0.96939129 0.99782723 0.77847815 0.97828513 0.84220856
#  [49] 0.77498668 0.73566741 0.99381107 0.54066128 0.95315611 0.50013393
#  [55] 0.68844342 0.74520028 0.16514595 0.11861773 0.08465283 0.36051381
#  [61] 0.45011896 0.56225228 0.25099257 0.49797830 0.76620138 0.56525546
#  [67] 0.82198787 0.38782227 0.03391125 0.54481381 0.85377699 0.82539415
#  [73] 0.24091615 0.51939780 0.54469198 0.58077103 0.10687167 0.29073837
#  [79] 0.42532498 0.24675344 0.08194067 0.53026491 0.92828655 0.76089430
#  [85] 0.52646303 0.27398965 0.60756707 0.07091846 0.63761032 0.04345673
#  [91] 0.10155367 0.58491009 0.25598589 0.09486649 0.93065089 0.36646414
#  [97] 0.64705306 0.36279580 0.14099775 0.70730197 0.34984586 0.87666553
# [103] 0.74397457 0.49684229 0.73255247 0.52797008 0.67744768 0.86509043
# [109] 0.09217174 0.42136633 0.65072149 0.45304871 0.13328715 0.38029101
# [115] 0.95852095 0.73360288 0.38930330 0.56595349 0.31827202 0.80399090
# [121] 0.85514551 0.46429223 0.54071319 0.61586654 0.94806373 0.63293815
# [127] 0.15626743 0.66710871 0.88508171 0.52775168 0.29255077 0.94878548
# [133] 0.59310418 0.72015882 0.95915288 0.67842108 0.97024417 0.60235304
# [139] 0.53468168 0.18971848 0.87635428 0.17879218 0.57852012 0.66212744
# [145] 0.44852737 0.30476561 0.71812737 0.49060640 0.15600580 0.95954138
# [151] 0.95897043 0.54473388 0.55058813 0.91301787 0.78910440 0.36621997
# [157] 0.77714247 0.76492023 0.92149788 0.81176019 0.11562892 0.93553841
# [163] 0.83202779 0.43585271 0.68895984 0.45834330 0.90998703 0.18890263
# [169] 0.97314644 0.90847862 0.98365062 0.98142749 0.98631370 0.91959810
# [175] 0.89126402 0.62324464 0.39420053 0.89500558 0.51848137 0.12788285
# [181] 0.15662026 0.95845073 0.96601170 0.22650968 0.86788255 0.98454434
# [187] 0.96479189 0.49502882 0.78990090 0.92503196 0.61689907 0.22208613
# [193] 0.56901693 0.72638482 0.29362577 0.94570386 0.87267333 0.87506467
# [199] 0.68468726 0.44133794 0.82085294 0.89958274 0.78855908 0.78463912
# [205] 0.95246685 0.62139595 0.98181468 0.51145935 0.60263681 0.77234417
# [211] 0.99593937 0.67316371
#   [1] 0.342573345 0.058098257 0.034925818 0.004002810 0.054155350 0.035835266
#   [7] 0.289073944 0.433821142 0.034991145 0.128520668 0.571533531 0.625940353
#  [13] 0.398848414 0.837361664 0.637611508 0.250930846 0.440076947 0.375511110
#  [19] 0.767566308 0.769945353 0.670219272 0.550179660 0.178700149 0.100676298
#  [25] 0.344095767 0.195723116 0.513971210 0.492657065 0.459987581 0.077406764
#  [31] 0.043592393 0.622781008 0.727111280 0.971854618 0.100472629 0.806976840
#  [37] 0.025994480 0.035295427 0.004465461 0.103275359 0.037584245 0.373504817
#  [43] 0.380501509 0.030608714 0.002172768 0.221521854 0.021714866 0.157791436
#  [49] 0.225013316 0.264332592 0.006188929 0.459338725 0.046843886 0.499866068
#  [55] 0.311556578 0.254799724 0.834854051 0.881382272 0.915347174 0.639486194
#  [61] 0.549881041 0.437747717 0.749007434 0.502021700 0.233798623 0.434744537
#  [67] 0.178012133 0.612177730 0.966088746 0.455186188 0.146223009 0.174605846
#  [73] 0.759083852 0.480602205 0.455308020 0.419228971 0.893128328 0.709261626
#  [79] 0.574675024 0.753246561 0.918059334 0.469735086 0.071713448 0.239105701
#  [85] 0.473536968 0.726010352 0.392432928 0.929081537 0.362389684 0.956543270
#  [91] 0.898446329 0.415089905 0.744014114 0.905133508 0.069349110 0.633535862
#  [97] 0.352946937 0.637204200 0.859002247 0.292698026 0.650154144 0.123334467
# [103] 0.256025434 0.503157705 0.267447531 0.472029924 0.322552323 0.134909570
# [109] 0.907828264 0.578633666 0.349278510 0.546951294 0.866712853 0.619708985
# [115] 0.041479051 0.266397119 0.610696703 0.434046507 0.681727976 0.196009099
# [121] 0.144854486 0.535707772 0.459286809 0.384133458 0.051936269 0.367061853
# [127] 0.843732566 0.332891285 0.114918292 0.472248316 0.707449228 0.051214516
# [133] 0.406895816 0.279841185 0.040847123 0.321578920 0.029755831 0.397646964
# [139] 0.465318322 0.810281515 0.123645723 0.821207821 0.421479881 0.337872565
# [145] 0.551472634 0.695234388 0.281872630 0.509393603 0.843994200 0.040458620
# [151] 0.041029572 0.455266118 0.449411869 0.086982131 0.210895598 0.633780032
# [157] 0.222857535 0.235079765 0.078502119 0.188239813 0.884371080 0.064461589
# [163] 0.167972207 0.564147294 0.311040163 0.541656703 0.090012968 0.811097369
# [169] 0.026853561 0.091521382 0.016349375 0.018572509 0.013686299 0.080401897
# [175] 0.108735979 0.376755357 0.605799466 0.104994416 0.481518626 0.872117147
# [181] 0.843379736 0.041549265 0.033988297 0.773490325 0.132117450 0.015455663
# [187] 0.035208106 0.504971176 0.210099101 0.074968040 0.383100927 0.777913868
# [193] 0.430983067 0.273615181 0.706374228 0.054296136 0.127326667 0.124935329
# [199] 0.315312743 0.558662057 0.179147065 0.100417256 0.211440921 0.215360880
# [205] 0.047533154 0.378604054 0.018185318 0.488540649 0.397363186 0.227655828
# [211] 0.004060626 0.326836288
# [20:14:43] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:43] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:46] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:47] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:50] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:50] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:54] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:54] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:58] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:14:58] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:02] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:02] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:06] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:06] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:11] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:11] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:14] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:14] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:17] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:17] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:20] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:21] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:24] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:24] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:27] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:28] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:31] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:31] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:35] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:35] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:39] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:40] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:42] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:43] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:46] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:46] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:49] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:50] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:53] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:54] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:57] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:15:57] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:01] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:01] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:05] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:05] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:09] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:10] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:12] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:13] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:16] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:16] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:19] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:19] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:27] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:30] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:30] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:34] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:34] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:38] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:16:38] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# besttune nrounds
# 100
# besttune max_depth
# 2
# besttune eta
# 0.3
# besttune gamma
# 0
# besttune colsample_bytree
# 0.6
# besttune min_child_weight
# 1
# besttune subsample
# 0.5
#     Cancer       Healthy
# 1   0.40958098   0.590419024
# 2   0.20245379   0.797546208
# 3   0.66680676   0.333193243
# 4   0.94675434   0.053245664
# 5   0.28965950   0.710340500
# 6   0.99055219   0.009447813
# 7   0.50429100   0.495709002
# 8   0.81321502   0.186784983
# 9   0.53910744   0.460892558
# 10  0.89044857   0.109551430
# 11  0.74759811   0.252401888
# 12  0.82825106   0.171748936
# 13  0.41951096   0.580489039
# 14  0.03879620   0.961203799
# 15  0.92835981   0.071640193
# 16  0.51703769   0.482962310
# 17  0.25228888   0.747711122
# 18  0.89659238   0.103407621
# 19  0.12954803   0.870451972
# 20  0.28780189   0.712198108
# 21  0.98897165   0.011028349
# 22  0.87444204   0.125557959
# 23  0.92340773   0.076592267
# 24  0.33125293   0.668747067
# 25  0.33987921   0.660120785
# 26  0.33896807   0.661031932
# 27  0.50793332   0.492066681
# 28  0.83019322   0.169806778
# 29  0.77458167   0.225418329
# 30  0.01615248   0.983847521
# ... ...          ...
# 183 0.8906666040 0.109333396
# 184 0.2051986158 0.794801384
# 185 0.0103250928 0.989674907
# 186 0.0009479713 0.999052029
# 187 0.4385891557 0.561410844
# 188 0.9338782430 0.066121757
# 189 0.8755651712 0.124434829
# 190 0.3514536321 0.648546368
# 191 0.2622042298 0.737795770
# 192 0.6131315231 0.386868477
# 193 0.9805457592 0.019454241
# 194 0.3269426227 0.673057377
# 195 0.9214297533 0.078570247
# 196 0.8382029533 0.161797047
# 197 0.9558299184 0.044170082
# 198 0.6692353487 0.330764651
# 199 0.3791091144 0.620890886
# 200 0.4020479321 0.597952068
# 201 0.9217191339 0.078280866
# 202 0.6907477379 0.309252262
# 203 0.9483673573 0.051632643
# 204 0.9916675687 0.008332431
# 205 0.5166945457 0.483305454
# 206 0.8475731015 0.152426898
# 207 0.8433191180 0.156680882
# 208 0.8842381239 0.115761876
# 209 0.6545148492 0.345485151
# 210 0.9981979728 0.001802027
# 211 0.9953722358 0.004627764
# 212 0.8544806242 0.145519376
#   [1] 0.4095809758 0.2024537921 0.6668067575 0.9467543364 0.2896595001
#   [6] 0.9905521870 0.5042909980 0.8132150173 0.5391074419 0.8904485703
#  [11] 0.7475981116 0.8282510638 0.4195109606 0.0387962013 0.9283598065
#  [16] 0.5170376897 0.2522888780 0.8965923786 0.1295480281 0.2878018916
#  [21] 0.9889716506 0.8744420409 0.9234077334 0.3312529325 0.3398792148
#  [26] 0.3389680684 0.5079333186 0.8301932216 0.7745816708 0.0161524788
#  [31] 0.5906432271 0.0106889708 0.2538110614 0.5624156594 0.7891127467
#  [36] 0.9831687212 0.8966152668 0.9455781579 0.7548170090 0.0178333987
#  [41] 0.1426229030 0.0309777781 0.0662373379 0.9994022846 0.1431083828
#  [46] 0.9916669726 0.7580637336 0.1942056566 0.9989923835 0.5745604038
#  [51] 0.9931396842 0.5328326225 0.9185206294 0.8701056242 0.8885263205
#  [56] 0.8787287474 0.8601915836 0.6788064241 0.6554715037 0.1757246107
#  [61] 0.4151081741 0.0749038830 0.5191748142 0.5953658223 0.5402383804
#  [66] 0.0283313654 0.4223791957 0.1520016193 0.4020510912 0.8243521452
#  [71] 0.3972362578 0.7302895188 0.1516652107 0.0558064170 0.6504911780
#  [76] 0.2428053468 0.1898751408 0.2600896955 0.8261978030 0.3993074596
#  [81] 0.4872267246 0.7324706912 0.8728197813 0.4163776934 0.6223500371
#  [86] 0.2908737063 0.9786849022 0.7490396500 0.7415924668 0.8730952144
#  [91] 0.0147168888 0.9670826197 0.1775090992 0.2103474140 0.0701073185
#  [96] 0.7484927773 0.1704358608 0.3578529954 0.4981563389 0.6662966609
# [101] 0.2575805485 0.0893123373 0.4782064259 0.6690951586 0.0929607823
# [106] 0.8105967641 0.8044127226 0.4632026255 0.7227675319 0.7658943534
# [111] 0.0794393122 0.9094008207 0.0348008573 0.0777827278 0.6788791418
# [116] 0.1481598318 0.4883126616 0.5240747929 0.0732592642 0.4481310546
# [121] 0.2599135041 0.2589408457 0.5813682675 0.0557506047 0.2046779692
# [126] 0.7656781673 0.6975957751 0.3936237991 0.9529042840 0.3674924970
# [131] 0.0330793187 0.7491192818 0.1106724963 0.1167082638 0.0578588992
# [136] 0.7754312754 0.0087574255 0.4559463561 0.9156560302 0.8224433661
# [141] 0.4051496089 0.6254850030 0.3027608991 0.7482963800 0.1580848992
# [146] 0.7099998593 0.9463574290 0.0017713660 0.3617528081 0.0115504116
# [151] 0.0119416891 0.0073273513 0.0397252068 0.0568408109 0.5220154524
# [156] 0.0676785931 0.9853432178 0.4243443906 0.8181447387 0.8810036778
# [161] 0.9973395467 0.4053485990 0.0401410349 0.3412649632 0.5717720389
# [166] 0.9621565342 0.9923216701 0.1629168391 0.9592565894 0.2030581087
# [171] 0.9783748984 0.9934085608 0.8715313077 0.0466290489 0.6723168492
# [176] 0.5717921257 0.2870506644 0.7045101523 0.9167997837 0.4840781689
# [181] 0.5761218071 0.9931142926 0.8906666040 0.2051986158 0.0103250928
# [186] 0.0009479713 0.4385891557 0.9338782430 0.8755651712 0.3514536321
# [191] 0.2622042298 0.6131315231 0.9805457592 0.3269426227 0.9214297533
# [196] 0.8382029533 0.9558299184 0.6692353487 0.3791091144 0.4020479321
# [201] 0.9217191339 0.6907477379 0.9483673573 0.9916675687 0.5166945457
# [206] 0.8475731015 0.8433191180 0.8842381239 0.6545148492 0.9981979728
# [211] 0.9953722358 0.8544806242
#   [1] 0.5904190242 0.7975462079 0.3331932425 0.0532456636 0.7103404999
#   [6] 0.0094478130 0.4957090020 0.1867849827 0.4608925581 0.1095514297
#  [11] 0.2524018884 0.1717489362 0.5804890394 0.9612037987 0.0716401935
#  [16] 0.4829623103 0.7477111220 0.1034076214 0.8704519719 0.7121981084
#  [21] 0.0110283494 0.1255579591 0.0765922666 0.6687470675 0.6601207852
#  [26] 0.6610319316 0.4920666814 0.1698067784 0.2254183292 0.9838475212
#  [31] 0.4093567729 0.9893110292 0.7461889386 0.4375843406 0.2108872533
#  [36] 0.0168312788 0.1033847332 0.0544218421 0.2451829910 0.9821666013
#  [41] 0.8573770970 0.9690222219 0.9337626621 0.0005977154 0.8568916172
#  [46] 0.0083330274 0.2419362664 0.8057943434 0.0010076165 0.4254395962
#  [51] 0.0068603158 0.4671673775 0.0814793706 0.1298943758 0.1114736795
#  [56] 0.1212712526 0.1398084164 0.3211935759 0.3445284963 0.8242753893
#  [61] 0.5848918259 0.9250961170 0.4808251858 0.4046341777 0.4597616196
#  [66] 0.9716686346 0.5776208043 0.8479983807 0.5979489088 0.1756478548
#  [71] 0.6027637422 0.2697104812 0.8483347893 0.9441935830 0.3495088220
#  [76] 0.7571946532 0.8101248592 0.7399103045 0.1738021970 0.6006925404
#  [81] 0.5127732754 0.2675293088 0.1271802187 0.5836223066 0.3776499629
#  [86] 0.7091262937 0.0213150978 0.2509603500 0.2584075332 0.1269047856
#  [91] 0.9852831112 0.0329173803 0.8224909008 0.7896525860 0.9298926815
#  [96] 0.2515072227 0.8295641392 0.6421470046 0.5018436611 0.3337033391
# [101] 0.7424194515 0.9106876627 0.5217935741 0.3309048414 0.9070392177
# [106] 0.1894032359 0.1955872774 0.5367973745 0.2772324681 0.2341056466
# [111] 0.9205606878 0.0905991793 0.9651991427 0.9222172722 0.3211208582
# [116] 0.8518401682 0.5116873384 0.4759252071 0.9267407358 0.5518689454
# [121] 0.7400864959 0.7410591543 0.4186317325 0.9442493953 0.7953220308
# [126] 0.2343218327 0.3024042249 0.6063762009 0.0470957160 0.6325075030
# [131] 0.9669206813 0.2508807182 0.8893275037 0.8832917362 0.9421411008
# [136] 0.2245687246 0.9912425745 0.5440536439 0.0843439698 0.1775566339
# [141] 0.5948503911 0.3745149970 0.6972391009 0.2517036200 0.8419151008
# [146] 0.2900001407 0.0536425710 0.9982286340 0.6382471919 0.9884495884
# [151] 0.9880583109 0.9926726487 0.9602747932 0.9431591891 0.4779845476
# [156] 0.9323214069 0.0146567822 0.5756556094 0.1818552613 0.1189963222
# [161] 0.0026604533 0.5946514010 0.9598589651 0.6587350368 0.4282279611
# [166] 0.0378434658 0.0076783299 0.8370831609 0.0407434106 0.7969418913
# [171] 0.0216251016 0.0065914392 0.1284686923 0.9533709511 0.3276831508
# [176] 0.4282078743 0.7129493356 0.2954898477 0.0832002163 0.5159218311
# [181] 0.4238781929 0.0068857074 0.1093333960 0.7948013842 0.9896749072
# [186] 0.9990520287 0.5614108443 0.0661217570 0.1244348288 0.6485463679
# [191] 0.7377957702 0.3868684769 0.0194542408 0.6730573773 0.0785702467
# [196] 0.1617970467 0.0441700816 0.3307646513 0.6208908856 0.5979520679
# [201] 0.0782808661 0.3092522621 0.0516326427 0.0083324313 0.4833054543
# [206] 0.1524268985 0.1566808820 0.1157618761 0.3454851508 0.0018020272
# [211] 0.0046277642 0.1455193758
# [20:19:52] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:19:52] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:19:55] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:19:56] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:19:59] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:19:59] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:03] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:03] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:07] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:07] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:10] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:11] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:15] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:15] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:19] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:20] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:22] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:29] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:30] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:33] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:33] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:36] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:37] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:40] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:40] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:44] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:44] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:48] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:48] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:51] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:51] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:54] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:55] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:58] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:20:58] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:02] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:03] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:06] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:06] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:10] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:10] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:14] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:15] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:19] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:20] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:22] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:29] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:29] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:33] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:33] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:36] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:36] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:40] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:40] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:44] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:44] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:48] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:21:48] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# besttune nrounds
# 100
# besttune max_depth
# 1
# besttune eta
# 0.4
# besttune gamma
# 0
# besttune colsample_bytree
# 0.8
# besttune min_child_weight
# 1
# besttune subsample
# 1
#     Cancer     Healthy
# 1   0.61137825 0.388621747
# 2   0.99404812 0.005951881
# 3   0.13522959 0.864770412
# 4   0.29693270 0.703067303
# 5   0.68554825 0.314451754
# 6   0.39004380 0.609956205
# 7   0.77722484 0.222775161
# 8   0.94384891 0.056151092
# 9   0.99499559 0.005004406
# 10  0.18312792 0.816872075
# 11  0.99761057 0.002389431
# 12  0.15444088 0.845559120
# 13  0.24923304 0.750766963
# 14  0.55034447 0.449655533
# 15  0.69808811 0.301911891
# 16  0.59768176 0.402318239
# 17  0.98253995 0.017460048
# 18  0.87492228 0.125077724
# 19  0.29265553 0.707344472
# 20  0.84706068 0.152939320
# 21  0.02655877 0.973441228
# 22  0.10908726 0.890912741
# 23  0.03358279 0.966417212
# 24  0.08694897 0.913051032
# 25  0.16288531 0.837114692
# 26  0.56352037 0.436479628
# 27  0.09214078 0.907859221
# 28  0.17909767 0.820902333
# 29  0.94280219 0.057197809
# 30  0.58814609 0.411853909
# ... ...        ...
# 183 0.47846931 5.215307e-01
# 184 0.86341929 1.365807e-01
# 185 0.04560865 9.543914e-01
# 186 0.93852997 6.147003e-02
# 187 0.69414276 3.058572e-01
# 188 0.89546484 1.045352e-01
# 189 0.27820805 7.217920e-01
# 190 0.07973062 9.202694e-01
# 191 0.60641438 3.935856e-01
# 192 0.77457345 2.254266e-01
# 193 0.15390095 8.460990e-01
# 194 0.02644740 9.735526e-01
# 195 0.77035826 2.296417e-01
# 196 0.91165507 8.834493e-02
# 197 0.72213352 2.778665e-01
# 198 0.75733328 2.426667e-01
# 199 0.88886780 1.111322e-01
# 200 0.97059488 2.940512e-02
# 201 0.96707278 3.292722e-02
# 202 0.99693406 3.065944e-03
# 203 0.97016191 2.983809e-02
# 204 0.97256720 2.743280e-02
# 205 0.73829949 2.617005e-01
# 206 0.96869546 3.130454e-02
# 207 0.94418621 5.581379e-02
# 208 0.50420070 4.957993e-01
# 209 0.23235127 7.676487e-01
# 210 0.99651366 3.486335e-03
# 211 0.99961901 3.809929e-04
# 212 0.99997330 2.670288e-05
#   [1] 0.611378253 0.994048119 0.135229588 0.296932697 0.685548246 0.390043795
#   [7] 0.777224839 0.943848908 0.994995594 0.183127925 0.997610569 0.154440880
#  [13] 0.249233037 0.550344467 0.698088109 0.597681761 0.982539952 0.874922276
#  [19] 0.292655528 0.847060680 0.026558772 0.109087259 0.033582788 0.086948968
#  [25] 0.162885308 0.563520372 0.092140779 0.179097667 0.942802191 0.588146091
#  [31] 0.061996233 0.013406005 0.997868896 0.311256856 0.196658358 0.978883743
#  [37] 0.905324936 0.911540985 0.990582705 0.231888160 0.738309145 0.970052779
#  [43] 0.337949425 0.980812311 0.999673486 0.255698383 0.996439040 0.782623529
#  [49] 0.226402640 0.984797001 0.943501234 0.786542654 0.891016543 0.890271664
#  [55] 0.995709896 0.999932289 0.898104846 0.947449386 0.942941904 0.799946904
#  [61] 0.917974710 0.207117945 0.045796085 0.971910119 0.444544405 0.749408841
#  [67] 0.942710638 0.075238101 0.625907183 0.677135825 0.301374793 0.664239526
#  [73] 0.639505625 0.177093416 0.149450153 0.125423625 0.867231667 0.782225847
#  [79] 0.192004457 0.804753900 0.984853864 0.129220068 0.298739165 0.402019799
#  [85] 0.498679668 0.105490640 0.733153343 0.065835185 0.684405625 0.029184667
#  [91] 0.985000134 0.343629509 0.491057396 0.049194727 0.566939175 0.869668841
#  [97] 0.130333394 0.949775398 0.979902685 0.873177707 0.683936000 0.530484974
# [103] 0.506711423 0.255869508 0.374256134 0.051155098 0.160927385 0.319853783
# [109] 0.082206406 0.745722055 0.783952177 0.036595561 0.272802413 0.089696400
# [115] 0.660387516 0.518083096 0.536603630 0.342079878 0.882662117 0.456805050
# [121] 0.633610129 0.103310473 0.832783580 0.415395081 0.949156165 0.065616593
# [127] 0.861037791 0.063345388 0.707396746 0.119885512 0.625682771 0.458934575
# [133] 0.928959131 0.180044532 0.500528097 0.946594417 0.262677073 0.466863871
# [139] 0.597404540 0.981719911 0.635180891 0.978547335 0.820351839 0.942029178
# [145] 0.921047151 0.006066492 0.055376478 0.012472415 0.004144214 0.054345895
# [151] 0.027308246 0.523209453 0.026311284 0.167119816 0.762773812 0.117939629
# [157] 0.481956214 0.984658122 0.423607409 0.920302331 0.999316454 0.416065067
# [163] 0.899173200 0.257689327 0.882107973 0.990437806 0.018731629 0.822405457
# [169] 0.115310557 0.232818678 0.895649195 0.999747336 0.970195234 0.606190979
# [175] 0.626094937 0.861581683 0.949628532 0.701795757 0.888465583 0.947821736
# [181] 0.675754964 0.014040742 0.478469312 0.863419294 0.045608647 0.938529968
# [187] 0.694142759 0.895464838 0.278208047 0.079730622 0.606414378 0.774573445
# [193] 0.153900951 0.026447397 0.770358264 0.911655068 0.722133517 0.757333279
# [199] 0.888867795 0.970594883 0.967072785 0.996934056 0.970161915 0.972567201
# [205] 0.738299489 0.968695462 0.944186211 0.504200697 0.232351273 0.996513665
# [211] 0.999619007 0.999973297
#   [1] 3.886217e-01 5.951881e-03 8.647704e-01 7.030673e-01 3.144518e-01
#   [6] 6.099562e-01 2.227752e-01 5.615109e-02 5.004406e-03 8.168721e-01
#  [11] 2.389431e-03 8.455591e-01 7.507670e-01 4.496555e-01 3.019119e-01
#  [16] 4.023182e-01 1.746005e-02 1.250777e-01 7.073445e-01 1.529393e-01
#  [21] 9.734412e-01 8.909127e-01 9.664172e-01 9.130510e-01 8.371147e-01
#  [26] 4.364796e-01 9.078592e-01 8.209023e-01 5.719781e-02 4.118539e-01
#  [31] 9.380038e-01 9.865940e-01 2.131104e-03 6.887431e-01 8.033416e-01
#  [36] 2.111626e-02 9.467506e-02 8.845901e-02 9.417295e-03 7.681118e-01
#  [41] 2.616909e-01 2.994722e-02 6.620506e-01 1.918769e-02 3.265142e-04
#  [46] 7.443016e-01 3.560960e-03 2.173765e-01 7.735974e-01 1.520300e-02
#  [51] 5.649877e-02 2.134573e-01 1.089835e-01 1.097283e-01 4.290104e-03
#  [56] 6.771088e-05 1.018952e-01 5.255061e-02 5.705810e-02 2.000531e-01
#  [61] 8.202529e-02 7.928821e-01 9.542039e-01 2.808988e-02 5.554556e-01
#  [66] 2.505912e-01 5.728936e-02 9.247619e-01 3.740928e-01 3.228642e-01
#  [71] 6.986252e-01 3.357605e-01 3.604944e-01 8.229066e-01 8.505498e-01
#  [76] 8.745764e-01 1.327683e-01 2.177742e-01 8.079955e-01 1.952461e-01
#  [81] 1.514614e-02 8.707799e-01 7.012608e-01 5.979802e-01 5.013203e-01
#  [86] 8.945094e-01 2.668467e-01 9.341648e-01 3.155944e-01 9.708153e-01
#  [91] 1.499987e-02 6.563705e-01 5.089426e-01 9.508053e-01 4.330608e-01
#  [96] 1.303312e-01 8.696666e-01 5.022460e-02 2.009732e-02 1.268223e-01
# [101] 3.160640e-01 4.695150e-01 4.932886e-01 7.441305e-01 6.257439e-01
# [106] 9.488449e-01 8.390726e-01 6.801462e-01 9.177936e-01 2.542779e-01
# [111] 2.160478e-01 9.634044e-01 7.271976e-01 9.103036e-01 3.396125e-01
# [116] 4.819169e-01 4.633964e-01 6.579201e-01 1.173379e-01 5.431949e-01
# [121] 3.663899e-01 8.966895e-01 1.672164e-01 5.846049e-01 5.084383e-02
# [126] 9.343834e-01 1.389622e-01 9.366546e-01 2.926033e-01 8.801145e-01
# [131] 3.743172e-01 5.410654e-01 7.104087e-02 8.199555e-01 4.994719e-01
# [136] 5.340558e-02 7.373229e-01 5.331361e-01 4.025955e-01 1.828009e-02
# [141] 3.648191e-01 2.145267e-02 1.796482e-01 5.797082e-02 7.895285e-02
# [146] 9.939335e-01 9.446235e-01 9.875276e-01 9.958558e-01 9.456541e-01
# [151] 9.726918e-01 4.767905e-01 9.736887e-01 8.328802e-01 2.372262e-01
# [156] 8.820604e-01 5.180438e-01 1.534188e-02 5.763926e-01 7.969767e-02
# [161] 6.835461e-04 5.839349e-01 1.008268e-01 7.423107e-01 1.178920e-01
# [166] 9.562194e-03 9.812684e-01 1.775945e-01 8.846894e-01 7.671813e-01
# [171] 1.043508e-01 2.526641e-04 2.980477e-02 3.938090e-01 3.739051e-01
# [176] 1.384183e-01 5.037147e-02 2.982042e-01 1.115344e-01 5.217826e-02
# [181] 3.242450e-01 9.859593e-01 5.215307e-01 1.365807e-01 9.543914e-01
# [186] 6.147003e-02 3.058572e-01 1.045352e-01 7.217920e-01 9.202694e-01
# [191] 3.935856e-01 2.254266e-01 8.460990e-01 9.735526e-01 2.296417e-01
# [196] 8.834493e-02 2.778665e-01 2.426667e-01 1.111322e-01 2.940512e-02
# [201] 3.292722e-02 3.065944e-03 2.983809e-02 2.743280e-02 2.617005e-01
# [206] 3.130454e-02 5.581379e-02 4.957993e-01 7.676487e-01 3.486335e-03
# [211] 3.809929e-04 2.670288e-05
# [20:25:37] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:37] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:40] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:41] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:44] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:44] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:48] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:49] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:52] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:53] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:56] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:25:57] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:01] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:01] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:06] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:06] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:09] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:09] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:12] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:12] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:15] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:16] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:19] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:20] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:23] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:31] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:31] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:35] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:35] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:38] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:38] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:42] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:42] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:45] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:45] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:49] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:50] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:53] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:53] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:57] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:26:57] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:01] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:01] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:05] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:06] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:08] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:09] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:12] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:12] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:15] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:15] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:19] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:19] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:22] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:22] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:26] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:30] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:31] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:34] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# [20:27:35] WARNING: amalgamation/../src/c_api/c_api.cc:718: `ntree_limit` is deprecated, use `iteration_range` instead.
# besttune nrounds
# 50
# besttune max_depth
# 2
# besttune eta
# 0.4
# besttune gamma
# 0
# besttune colsample_bytree
# 0.6
# besttune min_child_weight
# 1
# besttune subsample
# 0.5
#     Cancer     Healthy
# 1   0.68581545 0.3141845465
# 2   0.99955386 0.0004461408
# 3   0.14670347 0.8532965332
# 4   0.92440504 0.0755949616
# 5   0.98866826 0.0113317370
# 6   0.98827738 0.0117226243
# 7   0.98392177 0.0160782337
# 8   0.99963963 0.0003603697
# 9   0.91806120 0.0819388032
# 10  0.92864096 0.0713590384
# 11  0.09232613 0.9076738730
# 12  0.83034611 0.1696538925
# 13  0.28015366 0.7198463380
# 14  0.91732895 0.0826710463
# 15  0.68967324 0.3103267550
# 16  0.98738074 0.0126192570
# 17  0.34415537 0.6558446288
# 18  0.93458241 0.0654175878
# 19  0.68900406 0.3109959364
# 20  0.73733652 0.2626634836
# 21  0.92240983 0.0775901675
# 22  0.53549957 0.4645004272
# 23  0.54595137 0.4540486336
# 24  0.10456875 0.8954312503
# 25  0.02661698 0.9733830150
# 26  0.05660519 0.9433948137
# 27  0.96868974 0.0313102603
# 28  0.08234727 0.9176527262
# 29  0.70067108 0.2993289232
# 30  0.07687513 0.9231248721
# ... ...        ...
# 183 0.15633111 0.843668893
# 184 0.17093997 0.829060033
# 185 0.01606282 0.983937178
# 186 0.36266768 0.637332320
# 187 0.17788659 0.822113410
# 188 0.96013725 0.039862752
# 189 0.34211951 0.657880485
# 190 0.40453252 0.595467478
# 191 0.38066670 0.619333297
# 192 0.04992212 0.950077880
# 193 0.34170580 0.658294201
# 194 0.45313260 0.546867400
# 195 0.92711174 0.072888255
# 196 0.23421985 0.765780151
# 197 0.56456912 0.435430884
# 198 0.06135723 0.938642766
# 199 0.58309370 0.416906297
# 200 0.78110605 0.218893945
# 201 0.32245806 0.677541941
# 202 0.59410417 0.405895829
# 203 0.41257700 0.587422997
# 204 0.97843277 0.021567225
# 205 0.97616208 0.023837924
# 206 0.99835443 0.001645565
# 207 0.71593201 0.284067988
# 208 0.51434863 0.485651374
# 209 0.95361471 0.046385288
# 210 0.83605260 0.163947403
# 211 0.97882712 0.021172881
# 212 0.75994384 0.240056157
#   [1] 0.685815454 0.999553859 0.146703467 0.924405038 0.988668263 0.988277376
#   [7] 0.983921766 0.999639630 0.918061197 0.928640962 0.092326127 0.830346107
#  [13] 0.280153662 0.917328954 0.689673245 0.987380743 0.344155371 0.934582412
#  [19] 0.689004064 0.737336516 0.922409832 0.535499573 0.545951366 0.104568750
#  [25] 0.026616985 0.056605186 0.968689740 0.082347274 0.700671077 0.076875128
#  [31] 0.768513680 0.442744821 0.055828433 0.433232814 0.498736173 0.308944941
#  [37] 0.995757997 0.612071276 0.801608980 0.989148319 0.492992461 0.571803212
#  [43] 0.312886953 0.999698400 0.995417953 0.997649610 0.222102240 0.880223036
#  [49] 0.997441411 0.997128665 0.272159040 0.862765789 0.067804441 0.364871264
#  [55] 0.289971560 0.008086628 0.027469022 0.496315062 0.110553108 0.200196385
#  [61] 0.896481037 0.918809652 0.012712835 0.033090912 0.950554907 0.494666219
#  [67] 0.034869291 0.832122743 0.135530025 0.520838082 0.120946847 0.199768513
#  [73] 0.968597472 0.144449830 0.743757427 0.115463547 0.455412835 0.306585044
#  [79] 0.736821473 0.767258823 0.271985024 0.444379002 0.786675274 0.044237364
#  [85] 0.082332179 0.860034943 0.168303311 0.976765990 0.304869950 0.168704912
#  [91] 0.026503967 0.795481443 0.829769671 0.544348598 0.568974137 0.492497653
#  [97] 0.597186327 0.097235329 0.195060194 0.320814043 0.044940975 0.091214746
# [103] 0.051928286 0.159228534 0.026432838 0.824651778 0.131940648 0.945693552
# [109] 0.735218287 0.207958654 0.520475388 0.309591800 0.963715672 0.843941391
# [115] 0.402200609 0.733252406 0.020737318 0.152789012 0.120679326 0.022960430
# [121] 0.453216314 0.016293343 0.669822752 0.498814315 0.114195257 0.362826169
# [127] 0.028256187 0.220291898 0.392714590 0.060791764 0.964088380 0.115735665
# [133] 0.889045060 0.432441711 0.974444091 0.155072376 0.136593997 0.948979557
# [139] 0.636578858 0.985250175 0.388686985 0.313284397 0.063466817 0.894710600
# [145] 0.153291717 0.473650485 0.037404902 0.856341720 0.756024957 0.814166546
# [151] 0.670412838 0.959233463 0.367858768 0.481449187 0.904243946 0.332447499
# [157] 0.913519859 0.968518734 0.433251649 0.352945507 0.095388256 0.649750650
# [163] 0.133341864 0.201552406 0.659471214 0.874205351 0.011123182 0.030372052
# [169] 0.605972111 0.987742066 0.903932095 0.313718170 0.579451025 0.997768998
# [175] 0.504279912 0.092726648 0.820111573 0.928372443 0.921610475 0.284035593
# [181] 0.189065456 0.997325540 0.156331107 0.170939967 0.016062822 0.362667680
# [187] 0.177886590 0.960137248 0.342119515 0.404532522 0.380666703 0.049922120
# [193] 0.341705799 0.453132600 0.927111745 0.234219849 0.564569116 0.061357234
# [199] 0.583093703 0.781106055 0.322458059 0.594104171 0.412577003 0.978432775
# [205] 0.976162076 0.998354435 0.715932012 0.514348626 0.953614712 0.836052597
# [211] 0.978827119 0.759943843
#   [1] 0.3141845465 0.0004461408 0.8532965332 0.0755949616 0.0113317370
#   [6] 0.0117226243 0.0160782337 0.0003603697 0.0819388032 0.0713590384
#  [11] 0.9076738730 0.1696538925 0.7198463380 0.0826710463 0.3103267550
#  [16] 0.0126192570 0.6558446288 0.0654175878 0.3109959364 0.2626634836
#  [21] 0.0775901675 0.4645004272 0.4540486336 0.8954312503 0.9733830150
#  [26] 0.9433948137 0.0313102603 0.9176527262 0.2993289232 0.9231248721
#  [31] 0.2314863205 0.5572551787 0.9441715665 0.5667671859 0.5012638271
#  [36] 0.6910550594 0.0042420030 0.3879287243 0.1983910203 0.0108516812
#  [41] 0.5070075393 0.4281967878 0.6871130466 0.0003015995 0.0045820475
#  [46] 0.0023503900 0.7778977603 0.1197769642 0.0025585890 0.0028713346
#  [51] 0.7278409600 0.1372342110 0.9321955591 0.6351287365 0.7100284398
#  [56] 0.9919133717 0.9725309778 0.5036849380 0.8894468918 0.7998036146
#  [61] 0.1035189629 0.0811903477 0.9872871647 0.9669090882 0.0494450927
#  [66] 0.5053337812 0.9651307091 0.1678772569 0.8644699752 0.4791619182
#  [71] 0.8790531531 0.8002314866 0.0314025283 0.8555501699 0.2562425733
#  [76] 0.8845364526 0.5445871651 0.6934149563 0.2631785274 0.2327411771
#  [81] 0.7280149758 0.5556209981 0.2133247256 0.9557626359 0.9176678210
#  [86] 0.1399650574 0.8316966891 0.0232340097 0.6951300502 0.8312950879
#  [91] 0.9734960329 0.2045185566 0.1702303290 0.4556514025 0.4310258627
#  [96] 0.5075023472 0.4028136730 0.9027646706 0.8049398065 0.6791859567
# [101] 0.9550590254 0.9087852538 0.9480717145 0.8407714665 0.9735671617
# [106] 0.1753482223 0.8680593520 0.0543064475 0.2647817135 0.7920413464
# [111] 0.4795246124 0.6904082000 0.0362843275 0.1560586095 0.5977993906
# [116] 0.2667475939 0.9792626817 0.8472109884 0.8793206736 0.9770395700
# [121] 0.5467836857 0.9837066568 0.3301772475 0.5011856854 0.8858047426
# [126] 0.6371738315 0.9717438128 0.7797081023 0.6072854102 0.9392082356
# [131] 0.0359116197 0.8842643350 0.1109549403 0.5675582886 0.0255559087
# [136] 0.8449276239 0.8634060025 0.0510204434 0.3634211421 0.0147498250
# [141] 0.6113130152 0.6867156029 0.9365331829 0.1052893996 0.8467082828
# [146] 0.5263495147 0.9625950977 0.1436582804 0.2439750433 0.1858334541
# [151] 0.3295871615 0.0407665372 0.6321412325 0.5185508132 0.0957560539
# [156] 0.6675525010 0.0864801407 0.0314812660 0.5667483509 0.6470544934
# [161] 0.9046117440 0.3502493501 0.8666581362 0.7984475940 0.3405287862
# [166] 0.1257946491 0.9888768177 0.9696279485 0.3940278888 0.0122579336
# [171] 0.0960679054 0.6862818301 0.4205489755 0.0022310019 0.4957200885
# [176] 0.9072733521 0.1798884273 0.0716275573 0.0783895254 0.7159644067
# [181] 0.8109345436 0.0026744604 0.8436688930 0.8290600330 0.9839371778
# [186] 0.6373323202 0.8221134096 0.0398627520 0.6578804851 0.5954674780
# [191] 0.6193332970 0.9500778802 0.6582942009 0.5468674004 0.0728882551
# [196] 0.7657801509 0.4354308844 0.9386427663 0.4169062972 0.2188939452
# [201] 0.6775419414 0.4058958292 0.5874229968 0.0215672255 0.0238379240
# [206] 0.0016455650 0.2840679884 0.4856513739 0.0463852882 0.1639474034
# [211] 0.0211728811 0.2400561571

# %%
results <- tibble(results, .name_repair = "unique")
head(results)
# Out:
# New names:
# * prob -> prob...2
# * prob -> prob...3
#   observed prob...2  prob...3
# 1 1        0.5017044 0.5447889
# 2 1        0.3765051 0.3838233
# 3 1        0.8418328 0.8216452
# 4 1        0.6068647 0.6558366
# 5 1        0.4008763 0.5208182
# 6 1        0.3957804 0.2535260

# %%
saveRDS(results, file = snakemake@output[["boosting_output"]])

# %%
rocs <- roc(observed ~ predicted...2 + 
                    predicted...3 + 
                    predicted...4 + 
                    predicted...5 + 
                    predicted...6 +
                    predicted...7 +
                    predicted...8 + 
                    predicted...9 + 
                    predicted...10 + 
                    predicted...11, data = results)
ggroc(rocs)
# Out:
# plot without title

# %%
roc1 <- roc(results$observed, results$predicted...2)
roc2 <- roc(results$observed, results$predicted...3)
roc3 <- roc(results$observed, results$predicted...4)
roc4 <- roc(results$observed, results$predicted...5)
roc5 <- roc(results$observed, results$predicted...6)
roc6 <- roc(results$observed, results$predicted...7)
roc7 <- roc(results$observed, results$predicted...8)
roc8 <- roc(results$observed, results$predicted...9)
roc9 <- roc(results$observed, results$predicted...10)
roc10 <- roc(results$observed, results$predicted...11)
# Out:
# Area under the curve: 0.5

# %%
paste("Mean AUC over 10 repetitions of 10-fold CV: ", mean(c(auc(roc1), auc(roc2), auc(roc3), auc(roc4), auc(roc5), auc(roc6), auc(roc7), auc(roc8), auc(roc9), auc(roc10))), sep = "")

# %%
results_01 <- results %>% mutate(predicted...2_01 = ifelse(predicted...2 > 0.5, 1, 0), 
                                 predicted...3_01 = ifelse(predicted...3 > 0.5, 1, 0), 
                                 predicted...4_01 = ifelse(predicted...4 > 0.5, 1, 0),
                                 predicted...5_01 = ifelse(predicted...5 > 0.5, 1, 0),
                                 predicted...6_01 = ifelse(predicted...6 > 0.5, 1, 0),
                                 predicted...7_01 = ifelse(predicted...7 > 0.5, 1, 0),
                                 predicted...8_01 = ifelse(predicted...8 > 0.5, 1, 0),
                                 predicted...9_01 = ifelse(predicted...9 > 0.5, 1, 0),
                                 predicted...10_01 = ifelse(predicted...10 > 0.5, 1, 0),
                                 predicted...11_01 = ifelse(predicted...11 > 0.5, 1, 0))

# %%
error_rates <- c(mean(results_01$observed != results_01$predicted...2_01),
               mean(results_01$observed != results_01$predicted...3_01), 
               mean(results_01$observed != results_01$predicted...4_01),
               mean(results_01$observed != results_01$predicted...5_01),
               mean(results_01$observed != results_01$predicted...6_01),
               mean(results_01$observed != results_01$predicted...7_01),
               mean(results_01$observed != results_01$predicted...8_01),
               mean(results_01$observed != results_01$predicted...9_01), 
               mean(results_01$observed != results_01$predicted...10_01), 
               mean(results_01$observed != results_01$predicted...11_01))

error_rates

paste("Mean error rate over 10 repetitions of 10-fold CV: ", mean(error_rates), sep = "")

# %%
accuracies <- c(mean(results_01$observed == results_01$predicted...2_01),
               mean(results_01$observed == results_01$predicted...3_01), 
               mean(results_01$observed == results_01$predicted...4_01),
               mean(results_01$observed == results_01$predicted...5_01),
               mean(results_01$observed == results_01$predicted...6_01),
               mean(results_01$observed == results_01$predicted...7_01),
               mean(results_01$observed == results_01$predicted...8_01),
               mean(results_01$observed == results_01$predicted...9_01), 
               mean(results_01$observed == results_01$predicted...10_01), 
               mean(results_01$observed == results_01$predicted...11_01))

accuracies
paste("Mean accuracy over 10 repetitions of 10-fold CV: ", mean(accuracies), sep = "")
