# %%
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ──────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ─────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
coef <- readRDS("../Classification_output/ATAC/Binomial_models_output_chunked/Full_data/Combined_predictions/Boosting_Predictions_Full_data_Healthy.rds")

# %%
head(coef)
# Out:
#   cv_rep observed Cancer
# 1 1      Cancer   0.5573077
# 2 1      Cancer   0.1920449
# 3 1      Cancer   0.9994825
# 4 1      Cancer   0.2617980
# 5 1      Cancer   0.8086278
# 6 1      Cancer   0.8726091

# %%
data <- readRDS("../Summed_control/ATAC_Predictions_on_all_individuals/boosting_ATAC_pred_normalized_gaussian_smooth_trimmed.rds")

# %%
head(data)
# Out:
#   sample      bin       ATAC_observed ATAC_predicted
# 1 PGDX10344P1 chr10_400 0.5866651     0.5091804
# 2 PGDX10344P1 chr10_40  0.1996134     0.2085402
# 3 PGDX10344P1 chr10_4   0.5968816     0.3689053
# 4 PGDX10344P1 chr10_401 0.2905764     0.3291500
# 5 PGDX10344P1 chr10_402 0.2319729     0.4666202
# 6 PGDX10344P1 chr10_403 0.2262170     0.2536185

# %%
coef_df <- as.data.frame(as.matrix(coef))
coef_df <- rownames_to_column(coef_df, "feature")
colnames(coef_df) <- c("feature", "coef_value")
dim(coef_df)
coef_df
# Out:
# [1] 20323     2
#       feature               coef_value
# 1     (Intercept)           -1.225545
# 2     chr10_400_methylation  0.000000
# 3     chr10_40_methylation   0.000000
# 4     chr10_4_methylation    0.000000
# 5     chr10_401_methylation  0.000000
# 6     chr10_402_methylation  0.000000
# 7     chr10_403_methylation  0.000000
# 8     chr10_404_methylation  0.000000
# 9     chr10_405_methylation  0.000000
# 10    chr10_406_methylation  0.000000
# 11    chr10_407_methylation  0.000000
# 12    chr10_408_methylation  0.000000
# 13    chr10_409_methylation  0.000000
# 14    chr10_410_methylation  0.000000
# 15    chr10_41_methylation   0.000000
# 16    chr10_411_methylation  0.000000
# 17    chr10_412_methylation  0.000000
# 18    chr10_413_methylation  0.000000
# 19    chr10_414_methylation  0.000000
# 20    chr10_415_methylation  0.000000
# 21    chr10_416_methylation  0.000000
# 22    chr10_417_methylation  0.000000
# 23    chr10_418_methylation  0.000000
# ...

# %%
coef_df_nonzero <- coef_df %>% filter(abs(coef_value) != 0)
dim(coef_df_nonzero)
coef_df_nonzero
# Out:
# [1] 51  2
#    feature               coef_value
# 1  (Intercept)           -1.225545411
# 2  chr1_745_methylation  -0.105025968
# 3  chr1_747_methylation  -0.237686142
# 4  chr1_766_methylation  -0.114999244
# 5  chr1_769_methylation  -0.130493304
# 6  chr1_790_methylation  -0.146618855
# 7  chr12_441_methylation  0.299958277
# 8  chr12_259_methylation -0.375271438
# 9  chr12_261_methylation -0.027161385
# 10 chr13_404_methylation  0.368389734
# 11 chr13_415_methylation  0.162573724
# 12 chr1_130_methylation   0.331821003
# 13 chr13_119_methylation  0.585536833
# 14 chr1_16_methylation   -0.142730570
# 15 chr14_118_methylation -0.020133968
# 16 chr19_159_methylation  0.184120630
# 17 chr2_147_methylation  -0.151536997
# 18 chr4_523_methylation   0.059766472
# 19 chr4_359_methylation  -0.207025568
# 20 chr5_40_methylation   -0.628547909
# 21 chr6_303_methylation  -0.143757953
# 22 chr7_490_methylation  -0.003896311
# 23 chr7_169_methylation  -0.701320381
# ...
