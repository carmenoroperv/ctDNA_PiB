# %% [markdown]
# ## Standardizing the ATAC predictions

# %% [markdown]
# __This notebook takes an input file name (ATAC predictions made for all individudals) and an output file name. The input file is read in, predictions are standardized column by column and the standardized predictions are written to the output file.__

# %%
# packages

library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ purrr   0.3.2
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
input_filename <- "../data/ATAC_predictions_on_all_samples/ATAC_pred_smooth_gaussian_lasso_std_TRUE_formatted.csv"
output_filename <- "../data/ATAC_predictions_on_all_samples/ATAC_pred_smooth_gaussian_lasso_std_TRUE_formatted_standardized.csv"

# %%
df <- read.csv(input_filename)
head(df)
dim(df)
# Out:
# ERROR while rich displaying an object: Error in sprintf(wrap, header, body): 'fmt' length exceeds maximal format length 8192
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
# ...

# %%
scaled_df <- df
scaled_df <- scaled_df %>% mutate_at(scale, .vars = vars(-sample))

# %%
apply(scaled_df[2:10304], 2, mean)
# Out:
#     chr10_400      chr10_40       chr10_4     chr10_401     chr10_402
# -4.360647e-18 -1.694473e-17 -1.369373e-17 -1.233288e-17 -5.613554e-19
#     chr10_403     chr10_404     chr10_405     chr10_406     chr10_407
# -2.788783e-18 -6.152217e-18  1.445494e-17  5.950963e-18  1.704776e-17
#     chr10_408     chr10_409     chr10_410      chr10_41     chr10_411
# -2.624549e-18  1.127249e-17 -1.325294e-17  2.224334e-18 -1.470458e-17
#     chr10_412     chr10_413     chr10_414     chr10_415     chr10_416
# -2.698815e-18  6.598276e-18  5.900994e-18  1.706530e-17  3.710585e-18
#     chr10_417     chr10_418     chr10_419     chr10_420      chr10_42
# -1.616447e-17  1.816927e-18  1.802343e-18 -2.015034e-17 -7.565118e-18
#     chr10_421     chr10_422     chr10_423     chr10_424     chr10_425
# -1.125324e-17 -1.390529e-17 -1.161861e-17  5.813203e-18 -3.205617e-19
#     chr10_426     chr10_427     chr10_428     chr10_429     chr10_430
# ...

# %%
apply(scaled_df[2:10304], 2, sd)
# Out:
# chr10_400  chr10_40   chr10_4 chr10_401 chr10_402 chr10_403 chr10_404 chr10_405
#         1         1         1         1         1         1         1         1
# chr10_406 chr10_407 chr10_408 chr10_409 chr10_410  chr10_41 chr10_411 chr10_412
#         1         1         1         1         1         1         1         1
# chr10_413 chr10_414 chr10_415 chr10_416 chr10_417 chr10_418 chr10_419 chr10_420
#         1         1         1         1         1         1         1         1
#  chr10_42 chr10_421 chr10_422 chr10_423 chr10_424 chr10_425 chr10_426 chr10_427
#         1         1         1         1         1         1         1         1
# chr10_428 chr10_429 chr10_430  chr10_43 chr10_431 chr10_432 chr10_433 chr10_434
#         1         1         1         1         1         1         1         1
# chr10_435 chr10_436 chr10_437 chr10_438 chr10_439 chr10_440  chr10_44 chr10_441
#         1         1         1         1         1         1         1         1
# ...

# %%
head(scaled_df)
# Out:
# ERROR while rich displaying an object: Error in sprintf(wrap, header, body): 'fmt' length exceeds maximal format length 8192
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
# ...

# %%
write.csv(scaled_df, output_filename,  row.names = FALSE)
