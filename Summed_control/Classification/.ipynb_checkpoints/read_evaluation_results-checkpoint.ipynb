# %%
acc_gbm <- readRDS("Evaluation/Accuracy_GBM.rds")
acc_gbm
# Out:
#    Accuracy  AccuracyLower AccuracyUpper AccuracyNull CV_rep
# 1  0.6511628 0.6063131     0.6941088     0.5137421    CVrep1
# 2  0.6405920 0.5955200     0.6838938     0.5137421    CVrep2
# 3  0.6342495 0.5890550     0.6777538     0.5137421    CVrep3
# 4  0.6532770 0.6084745     0.6961491     0.5137421    CVrep4
# 5  0.6427061 0.5976768     0.6859386     0.5137421    CVrep5
# 6  0.6553911 0.6106368     0.6981884     0.5137421    CVrep6
# 7  0.6765328 0.6323117     0.7185294     0.5137421    CVrep7
# 8  0.6088795 0.5632748     0.6531140     0.5137421    CVrep8
# 9  0.6638478 0.6192953     0.7063362     0.5137421    CVrep9
# 10 0.6701903 0.6257992     0.7124372     0.5137421    CVrep10
# 11 0.6496829 0.6048357     0.6926449     0.5137421    mean

# %%
eval_metrics_gbm <- readRDS("Evaluation/Eval_metrics_GBM.rds")
eval_metrics_gbm
# Out:
#    Balanced Accuracy Sensitivity Specificity Precision Recall    CV_rep
# 1  0.6494453         0.5869565   0.7119342   0.6585366 0.5869565 CVrep1
# 2  0.6398551         0.6130435   0.6666667   0.6351351 0.6130435 CVrep2
# 3  0.6325192         0.5695652   0.6954733   0.6390244 0.5695652 CVrep3
# 4  0.6526660         0.6304348   0.6748971   0.6473214 0.6304348 CVrep4
# 5  0.6404008         0.5565217   0.7242798   0.6564103 0.5565217 CVrep5
# 6  0.6536769         0.5913043   0.7160494   0.6634146 0.5913043 CVrep6
# 7  0.6746019         0.6043478   0.7448560   0.6915423 0.6043478 CVrep7
# 8  0.6075953         0.5608696   0.6543210   0.6056338 0.5608696 CVrep8
# 9  0.6631866         0.6391304   0.6872428   0.6591928 0.6391304 CVrep9
# 10 0.6684291         0.6043478   0.7325103   0.6813725 0.6043478 CVrep10
# 11 0.6482376         0.5956522   0.7008230   0.6537584 0.5956522 mean

# %%
aucs_gbm <- readRDS("Evaluation/AUCs_GBM.rds")
aucs_gbm
# Out:
#    cv_rep case_control_auc
# 1  1      0.7160136
# 2  2      0.7034353
# 3  3      0.7044552
# 4  4      0.7012346
# 5  5      0.6990159
# 6  6      0.7073716
# 7  7      0.7343711
# 8  8      0.6563786
# 9  9      0.7118268
# 10 10     0.7218107
# 11 mean   0.7055487

# %%
acc_lasso <- readRDS("Evaluation/Accuracy_lasso.rds")
acc_lasso
# Out:
#    Accuracy  AccuracyLower AccuracyUpper AccuracyNull CV_rep
# 1  0.6997886 0.6562671     0.7407910     0.5137421    CVrep1
# 2  0.7061311 0.6628218     0.7468408     0.5137421    CVrep2
# 3  0.7040169 0.6606358     0.7448252     0.5137421    CVrep3
# 4  0.6934461 0.6497217     0.7347318     0.5137421    CVrep4
# 5  0.6976744 0.6540843     0.7387723     0.5137421    CVrep5
# 6  0.7145877 0.6715762     0.7548923     0.5137421    CVrep6
# 7  0.6892178 0.6453632     0.7306872     0.5137421    CVrep7
# 8  0.6913319 0.6475419     0.7327100     0.5137421    CVrep8
# 9  0.6871036 0.6431855     0.7286634     0.5137421    CVrep9
# 10 0.6955603 0.6519025     0.7367526     0.5137421    CVrep10
# 11 0.6978858 0.6543100     0.7389667     0.5137421    mean

# %%
eval_metrics_lasso <- readRDS("Evaluation/Eval_metrics_lasso.rds")
eval_metrics_lasso
# Out:
#    Balanced Accuracy Sensitivity Specificity Precision Recall    CV_rep
# 1  0.6971193         0.6000000   0.7942387   0.7340426 0.6000000 CVrep1
# 2  0.7035248         0.6086957   0.7983539   0.7407407 0.6086957 CVrep2
# 3  0.7015835         0.6130435   0.7901235   0.7343750 0.6130435 CVrep3
# 4  0.6909465         0.6000000   0.7818930   0.7225131 0.6000000 CVrep4
# 5  0.6948291         0.5913043   0.7983539   0.7351351 0.5913043 CVrep5
# 6  0.7119878         0.6173913   0.8065844   0.7513228 0.6173913 CVrep6
# 7  0.6867150         0.5956522   0.7777778   0.7172775 0.5956522 CVrep7
# 8  0.6885400         0.5869565   0.7901235   0.7258065 0.5869565 CVrep8
# 9  0.6848900         0.6043478   0.7654321   0.7091837 0.6043478 CVrep9
# 10 0.6933530         0.6130435   0.7736626   0.7193878 0.6130435 CVrep10
# 11 0.6953489         0.6030435   0.7876543   0.7289785 0.6030435 mean

# %%
aucs_lasso <- readRDS("Evaluation/AUCs_lasso.rds")
aucs_lasso
# Out:
#    cv_rep case_control_auc
# 1  1      0.7685632
# 2  2      0.7662194
# 3  3      0.7695115
# 4  4      0.7627304
# 5  5      0.7688853
# 6  6      0.7760780
# 7  7      0.7578458
# 8  8      0.7627483
# 9  9      0.7575416
# 10 10     0.7639649
# 11 mean   0.7652313
