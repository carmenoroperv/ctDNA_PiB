# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
library(methods)
Snakemake <- setClass(
    "Snakemake",
    slots = c(
        input = "list",
        output = "list",
        params = "list",
        wildcards = "list",
        threads = "numeric",
        log = "list",
        resources = "list",
        config = "list",
        rule = "character",
        bench_iteration = "numeric",
        scriptdir = "character",
        source = "function"
    )
)
snakemake <- Snakemake(
    input = list('data/ATAC_predictions_train_20_predict_80/ATAC_pred_lasso_normalized_trimmed_formatted_standardized.rds', 'data/sample_types.txt', "input_predictions" = 'data/ATAC_predictions_train_20_predict_80/ATAC_pred_lasso_normalized_trimmed_formatted_standardized.rds', "input_sample_types" = 'data/sample_types.txt'),
    output = list('Classification_output/PCA_Boosting_normalized_trimmed.rds', "boosting_output" = 'Classification_output/PCA_Boosting_normalized_trimmed.rds'),
    params = list(),
    wildcards = list(),
    threads = 5,
    log = list('logs/processed_notebooks/Classification/PCA_Boosting_normalized_trimmed.r.ipynb', "notebook" = 'logs/processed_notebooks/Classification/PCA_Boosting_normalized_trimmed.r.ipynb'),
    resources = list('mem_mb', 'disk_mb', 'tmpdir', 'time', "mem_mb" = 200000, "disk_mb" = 1000, "tmpdir" = '/scratch/56917347', "time" = '48:00:00'),
    config = list(),
    rule = 'PCA_boosting',
    bench_iteration = as.numeric(NA),
    scriptdir = '/faststorage/project/DELFI1/Workspaces/CarmenAndAnika/Classification/PCA_classification',
    source = function(...){
        wd <- getwd()
        setwd(snakemake@scriptdir)
        source(...)
        setwd(wd)
    }
)
setwd('/faststorage/project/DELFI1/Workspaces/CarmenAndAnika');

######## snakemake preamble end #########

# %%
library(dplyr)
library(class)
library(tidyverse)
library(pROC)
library(glmnet)

#install.packages('glmnetUtils')
library(glmnetUtils)


library(gbm)
library(caret)
install.packages("e1071")
library(e1071)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ readr   1.3.1
# ✔ tibble  3.1.4     ✔ purrr   0.3.4
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ ggplot2 3.1.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Type 'citation("pROC")' for a citation.
#
# Attaching package: ‘pROC’
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
#
# Loading required package: Matrix
#
# Attaching package: ‘Matrix’
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loaded glmnet 2.0-16
#
#
# Attaching package: ‘glmnet’
#
# The following object is masked from ‘package:pROC’:
#
#     auc
#
#
# Attaching package: ‘glmnetUtils’
#
# The following objects are masked from ‘package:glmnet’:
#
#     cv.glmnet, glmnet
#
# Loaded gbm 2.1.8
# Loading required package: lattice
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
#lasso_pred <- readRDS("../../data/ATAC_predictions_train_XX_predict_XX/ATAC_pred_lasso_normalized_trimmed_formatted_standardized.rds")
lasso_pred <- readRDS(snakemake@input[["input_predictions"]])

# %%
head(lasso_pred)
# Out:
# ERROR while rich displaying an object: Error in sprintf(wrap, header, body): 'fmt' length exceeds maximal format length 8192
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_latex.data.frame(obj)
# 9. repr_matrix_generic(obj, sprintf("\\begin{tabular}{%s}\n%%s%%s\\end{tabular}\n",
#  .     cols), "%s\\\\\n\\hline\n", "  &", " %s &", "%s", "\t%s\\\\\n",
#  .     "%s &", " %s &", escape_fun = latex_escape_vec, ...)
# 10. sprintf(wrap, header, body)
#    sample     chr10_400 chr10_40   chr10_4   chr10_401  chr10_402  chr10_403
# V1 PGDX16568P 0.7621097 -0.8032188 0.6402487 -0.8688929 -0.4792134 -0.5096581
# V2 PGDX16569P 0.7057109 -0.8227554 0.7868749 -1.0407754 -0.9284673 -0.4139074
# V3 PGDX16570P 0.4891340 -1.1448217 0.9478602 -1.0930696 -0.5115270 -0.7552269
# V4 PGDX16571P 0.6882727 -0.8585679 0.6248431 -0.8310281 -0.5335804 -0.5125528
# V5 PGDX16579P 0.5801896 -1.1674832 0.7883376 -1.0498406 -1.2475692 -0.7345196
# V6 PGDX16580P 0.6831409 -0.8712906 0.7199476 -1.1853489 -0.8520159 -0.6829992
#    chr10_404   chr10_405 chr10_406 ... chr9_39      chr9_391    chr9_392
# V1  0.02594817 0.7295906 0.7738027 ... -0.405123632  0.59187320 -0.29125018
# V2 -0.16594560 0.7765621 0.5761691 ... -0.849313481  0.39431325  0.05197526
# V3 -0.48824613 0.9537215 0.6624865 ... -0.871941533 -0.06389996 -0.22907645
# V4 -0.34185944 0.9281618 0.4768828 ... -0.005893625  0.18185487  0.32387927
# V5 -0.18778863 0.2546093 0.2920616 ... -0.067895629 -0.05197828 -0.18308631
# V6 -0.35499242 0.8598551 0.3870744 ... -0.735310376  0.36325245  0.20814984
#    chr9_393    chr9_394   chr9_395    chr9_396  chr9_397  chr9_398  chr9_399
# V1 -0.58276010  0.3792968 -0.04366948 0.9183014 0.7664238 0.9980457 -1.0572778
# V2 -0.36318168  0.1744439 -0.13785162 0.5392077 0.3942941 1.7972449 -0.3619464
# V3 -0.32470631 -0.6251958  0.17051719 0.6882020 0.1744819 1.4357406 -0.2330366
# V4  0.04577069  0.2752394  0.22750427 0.6333635 0.8413436 1.2819797  0.5629469
# V5 -0.70242368 -0.4281903 -0.06235782 1.0764914 1.1411410 0.8795170 -0.4910720
# V6 -0.50307962  0.2609116  0.53933999 1.0772367 0.6906960 1.7696570 -0.4181884

# %%
lasso_pred.pca <- prcomp(lasso_pred[2:10304], center = TRUE,scale. = TRUE)

# %%
head(lasso_pred.pca$x)
# Out:
#    PC1         PC2         PC3        PC4         PC5        PC6
# V1 -15.2265158   1.1439775  -8.296222  4.48245890 -1.3355241 4.8802111
# V2   4.3243724 -19.4159808  26.093334  9.00428915 -5.3011949 5.3605925
# V3  -4.6063199  -0.8040079   3.066747  6.76008180 -0.7531005 3.3614591
# V4  -8.5814328  -6.8163299 -14.337072 -0.09825629 -1.2567324 1.7686144
# V5  -0.6606702 -24.7348173 -28.097192 -7.80833623 -1.2275561 0.6568667
# V6  -5.2543993  -9.3039217  -8.371634  3.57135578 -1.5410358 4.1509389
#    PC7        PC8        PC9        PC10       ... PC415       PC416
# V1 -1.5523707  0.7999849 -4.7522280  2.7608014 ... -0.65800314  0.95169782
# V2 -2.9697958 10.1294220 14.1969498  5.4397945 ...  0.10647120  0.62135384
# V3  2.9378869 -2.6362632 -0.8766079 -1.5006157 ... -0.60783168  0.06371054
# V4  0.9196301 -0.4870796 -0.6504569  1.7541831 ...  0.08874938 -0.62098954
# V5 -0.4001172  0.6167319 -2.4452097  0.0269603 ...  0.96699400 -0.73553404
# V6  0.2083436 -2.0991876 -0.2124703 -1.5396283 ... -0.34177895 -1.09691623
#    PC417       PC418       PC419       PC420       PC421       PC422
# V1 -0.41084578  0.60852525 -0.07547477  0.01482042 -0.35238377  0.13045048
# V2  0.58600376  0.04862774  1.08341218 -0.03153724  0.44070032  0.09332012
# V3  0.75189183  0.58872501 -0.02765133  0.48785318  0.23444574 -0.24678547
# V4 -0.08304112  0.59493798  0.16777147 -0.03292807  0.04462314  0.46231486
# V5 -0.44843059 -0.19252807 -0.56773840  0.24895345 -0.29442997  0.40862739
# V6 -0.05334271  1.39384990 -0.09427847 -0.26940296 -0.23731892  0.80329505
#    PC423      PC424
# V1 -0.2041816 -8.784640e-15
# V2  0.2686092 -4.551914e-15
# V3  0.8521206 -9.006684e-15
# V4 -0.2803168 -1.239286e-14
# V5 -0.3039250 -1.214306e-14
# V6  0.1481473 -1.224021e-14

# %%
ggplot() +
  geom_point(aes(lasso_pred.pca$x[,1],lasso_pred.pca$x[,2])) +
  theme_minimal() +
  ylab('PC1') + xlab('PC2')
# Out:
# plot without title

# %%
var_exp <- tibble(PC = 1:dim(lasso_pred.pca$x)[2], 
                  Variance_Explained = lasso_pred.pca$sdev^2 / sum(lasso_pred.pca$sdev^2),
                  Cumulative_Variance_Explained = cumsum(Variance_Explained))

# %%
var_exp %>% 
  ggplot(aes(PC, Variance_Explained)) + 
  geom_line() + 
  geom_point() + 
  theme_minimal()
# Out:
# plot without title

# %%
sample_names <- as.data.frame(lasso_pred$sample)
colnames(sample_names) <- c("sample")
pca <- lasso_pred.pca$x[,1:50]

# %%
head(pca)
# Out:
#    PC1         PC2         PC3        PC4         PC5        PC6
# V1 -15.2265158   1.1439775  -8.296222  4.48245890 -1.3355241 4.8802111
# V2   4.3243724 -19.4159808  26.093334  9.00428915 -5.3011949 5.3605925
# V3  -4.6063199  -0.8040079   3.066747  6.76008180 -0.7531005 3.3614591
# V4  -8.5814328  -6.8163299 -14.337072 -0.09825629 -1.2567324 1.7686144
# V5  -0.6606702 -24.7348173 -28.097192 -7.80833623 -1.2275561 0.6568667
# V6  -5.2543993  -9.3039217  -8.371634  3.57135578 -1.5410358 4.1509389
#    PC7        PC8        PC9        PC10       ... PC41       PC42
# V1 -1.5523707  0.7999849 -4.7522280  2.7608014 ... -1.6209073  1.1454021
# V2 -2.9697958 10.1294220 14.1969498  5.4397945 ... -1.9620863 -2.0160985
# V3  2.9378869 -2.6362632 -0.8766079 -1.5006157 ... -1.1057902  0.4218852
# V4  0.9196301 -0.4870796 -0.6504569  1.7541831 ... -0.5791377  2.2918165
# V5 -0.4001172  0.6167319 -2.4452097  0.0269603 ...  3.4071570 -1.3237016
# V6  0.2083436 -2.0991876 -0.2124703 -1.5396283 ... -1.7189934 -1.0295196
#    PC43       PC44       PC45       PC46      PC47       PC48       PC49
# V1 -0.1013291 -1.5590984  1.4565019 0.1808208 -2.7773855 -0.5299759 2.1619511
# V2  1.8727879  1.9626121  1.8462839 1.2079163  1.1003376 -1.9753527 0.6114587
# V3 -0.3978684  1.3139833  2.1703696 1.4379112 -1.9227372 -0.5670856 1.2762748
# V4  0.6459708 -0.7596068 -0.9879893 0.2722558 -0.4618307 -1.8378491 0.4302889
# V5 -0.8310992  0.9592468  0.8136893 0.1197892  1.1093784 -2.1636222 0.3328450
# V6 -0.6557889 -1.3526760  1.3104467 1.3990342 -0.6996009 -0.3705912 0.5525779
#    PC50
# V1  1.03146426
# V2 -0.18072436
# V3 -1.71623194
# V4 -1.64355150
# V5 -2.54647392
# V6 -0.01810541

# %%
head(sample_names)
# Out:
#   sample
# 1 PGDX16568P
# 2 PGDX16569P
# 3 PGDX16570P
# 4 PGDX16571P
# 5 PGDX16579P
# 6 PGDX16580P

# %%
ATAC_pred <- cbind(sample_names, pca)

# %%
head(ATAC_pred)
# Out:
#    sample     PC1         PC2         PC3        PC4         PC5
# V1 PGDX16568P -15.2265158   1.1439775  -8.296222  4.48245890 -1.3355241
# V2 PGDX16569P   4.3243724 -19.4159808  26.093334  9.00428915 -5.3011949
# V3 PGDX16570P  -4.6063199  -0.8040079   3.066747  6.76008180 -0.7531005
# V4 PGDX16571P  -8.5814328  -6.8163299 -14.337072 -0.09825629 -1.2567324
# V5 PGDX16579P  -0.6606702 -24.7348173 -28.097192 -7.80833623 -1.2275561
# V6 PGDX16580P  -5.2543993  -9.3039217  -8.371634  3.57135578 -1.5410358
#    PC6       PC7        PC8        PC9        ... PC41       PC42
# V1 4.8802111 -1.5523707  0.7999849 -4.7522280 ... -1.6209073  1.1454021
# V2 5.3605925 -2.9697958 10.1294220 14.1969498 ... -1.9620863 -2.0160985
# V3 3.3614591  2.9378869 -2.6362632 -0.8766079 ... -1.1057902  0.4218852
# V4 1.7686144  0.9196301 -0.4870796 -0.6504569 ... -0.5791377  2.2918165
# V5 0.6568667 -0.4001172  0.6167319 -2.4452097 ...  3.4071570 -1.3237016
# V6 4.1509389  0.2083436 -2.0991876 -0.2124703 ... -1.7189934 -1.0295196
#    PC43       PC44       PC45       PC46      PC47       PC48       PC49
# V1 -0.1013291 -1.5590984  1.4565019 0.1808208 -2.7773855 -0.5299759 2.1619511
# V2  1.8727879  1.9626121  1.8462839 1.2079163  1.1003376 -1.9753527 0.6114587
# V3 -0.3978684  1.3139833  2.1703696 1.4379112 -1.9227372 -0.5670856 1.2762748
# V4  0.6459708 -0.7596068 -0.9879893 0.2722558 -0.4618307 -1.8378491 0.4302889
# V5 -0.8310992  0.9592468  0.8136893 0.1197892  1.1093784 -2.1636222 0.3328450
# V6 -0.6557889 -1.3526760  1.3104467 1.3990342 -0.6996009 -0.3705912 0.5525779
#    PC50
# V1  1.03146426
# V2 -0.18072436
# V3 -1.71623194
# V4 -1.64355150
# V5 -2.54647392
# V6 -0.01810541

# %%
#sample_types <- read.table("../../data/sample_types.txt", header = F, sep = " ")
sample_types <- read.table(file = snakemake@input[["input_sample_types"]], header = F, sep = " ")

colnames(sample_types) <- c("sample", "sample_type")
head(sample_types)
# Out:
#   sample      sample_type
# 1 PGDX10344P1 Gastric_cancer
# 2 PGDX10346P1 Gastric_cancer
# 3 PGDX10349P1 Gastric_cancer
# 4 PGDX10351P1 Gastric_cancer
# 5 PGDX10566P  Ovarian_Cancer
# 6 PGDX10567P  Ovarian_Cancer

# %%
data <- merge(ATAC_pred, sample_types, by="sample")
data <- data %>% mutate(sample_type01 = ifelse(sample_type == "Healthy", 0, 1))
head(data)
# Out:
#   sample      PC1        PC2        PC3        PC4        PC5        PC6
# 1 PGDX10344P1  -4.342131   1.953977 -13.968322   2.318305   1.685676 -3.381066
# 2 PGDX10346P1  -6.078536 -12.661175 -11.678871  -1.872324   1.336255 -1.996692
# 3 PGDX10349P1  48.179628 -48.671877  57.672198  10.976267 -20.122190 -4.259207
# 4 PGDX10351P1 -35.928939 -11.350262 -13.701368 -14.147165  -4.240782 -5.227815
# 5 PGDX10566P   -3.645149  -8.417624 -18.188105  -4.633597   1.470311 -1.048202
# 6 PGDX10567P    9.167948  -9.013273   9.812515   4.895645  -4.504976  4.545019
#   PC7        PC8        PC9         ... PC43       PC44      PC45
# 1  6.0445212 -1.1347791  1.74198197 ...  0.6274859 -2.622078  1.6339641
# 2 -6.4118319  7.9706470 12.11108040 ... -2.9572109 -2.308502  0.7707140
# 3  3.0733782  0.6075922  1.57203960 ...  0.6475888  2.037660 -1.7877125
# 4 -0.1563398  5.1853643 -1.26376760 ...  2.4307994  5.922993  2.1776501
# 5  3.6578793 -1.3577985 -0.59132535 ...  2.1880247 -4.290371  0.5627505
# 6  1.3597509 -2.8620042  0.01220041 ... -1.0443199  3.607826 -2.0018629
#   PC46       PC47       PC48       PC49        PC50       sample_type
# 1  0.2876357  2.4162404  1.8695959  0.08770358 -1.2166196 Gastric_cancer
# 2 -3.6516509 -3.0050707 -1.9374279 -0.15064911 -3.4388000 Gastric_cancer
# 3  2.0789376 -1.0851786 -0.2287387  0.90575811 -0.9010285 Gastric_cancer
# 4 -2.6065181  1.8807665  2.5498882 -3.57969961  1.5642893 Gastric_cancer
# 5  2.3363121 -0.2994595  2.8081674  2.42526637  1.0627620 Ovarian_Cancer
# 6  3.3426278 -1.0511282  0.7924274  0.98886233  6.8472585 Ovarian_Cancer
#   sample_type01
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
data <- data %>% select(-sample_type)

# %%
data <- data %>% select(-sample)
head(data)
# Out:
#   PC1        PC2        PC3        PC4        PC5        PC6       PC7
# 1  -4.342131   1.953977 -13.968322   2.318305   1.685676 -3.381066  6.0445212
# 2  -6.078536 -12.661175 -11.678871  -1.872324   1.336255 -1.996692 -6.4118319
# 3  48.179628 -48.671877  57.672198  10.976267 -20.122190 -4.259207  3.0733782
# 4 -35.928939 -11.350262 -13.701368 -14.147165  -4.240782 -5.227815 -0.1563398
# 5  -3.645149  -8.417624 -18.188105  -4.633597   1.470311 -1.048202  3.6578793
# 6   9.167948  -9.013273   9.812515   4.895645  -4.504976  4.545019  1.3597509
#   PC8        PC9         PC10        ... PC42       PC43       PC44
# 1 -1.1347791  1.74198197 -0.74881708 ... -2.8077276  0.6274859 -2.622078
# 2  7.9706470 12.11108040  5.72266372 ... -1.3210358 -2.9572109 -2.308502
# 3  0.6075922  1.57203960 -2.84910093 ...  0.7400773  0.6475888  2.037660
# 4  5.1853643 -1.26376760  0.05546772 ...  3.8996607  2.4307994  5.922993
# 5 -1.3577985 -0.59132535 -2.49310460 ...  1.2274091  2.1880247 -4.290371
# 6 -2.8620042  0.01220041  0.19581699 ...  2.7123738 -1.0443199  3.607826
#   PC45       PC46       PC47       PC48       PC49        PC50
# 1  1.6339641  0.2876357  2.4162404  1.8695959  0.08770358 -1.2166196
# 2  0.7707140 -3.6516509 -3.0050707 -1.9374279 -0.15064911 -3.4388000
# 3 -1.7877125  2.0789376 -1.0851786 -0.2287387  0.90575811 -0.9010285
# 4  2.1776501 -2.6065181  1.8807665  2.5498882 -3.57969961  1.5642893
# 5  0.5627505  2.3363121 -0.2994595  2.8081674  2.42526637  1.0627620
# 6 -2.0018629  3.3426278 -1.0511282  0.7924274  0.98886233  6.8472585
#   sample_type01
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
data$sample_type01 <- as.factor(data$sample_type01)

# %%
cross_validation <- function(dataset, k_inner_cv, k_outer_cv){
    
    observed  <- dataset$sample_type01
    return_tibble <- tibble(observed = observed)
    
    for (i in 1:k_outer_cv){ # repeated Cross-validation loop
    
    set.seed(i)
    cvfolds <- cut(seq_len(nrow(dataset)), breaks = k_inner_cv, labels = F)
    cvfolds <- sample(cvfolds)

    predicted <- rep(NA, nrow(dataset))
    
    for (n in 1:k_inner_cv){
        rows      <- which(cvfolds==n)
        testdata  <- dataset[rows,]
        testlabels <- testdata$sample_type01
        testdata <- testdata %>% select(-sample_type01)
        
        traindata <- dataset[-rows,]
        trainlabels <- traindata$sample_type01
        traindata <- traindata %>% select(-sample_type01)
     
        ################# Nested cross validation #######################
        set.seed(0)
        seeds <- vector(mode = "list", length = 11)
        for(i in 1:10) seeds[[i]]<- sample.int(n=1000, 18)
        #for the last model
        seeds[[11]]<-sample.int(1000, 1)

        trControl_gbm <- trainControl(method = "repeatedcv", 
                                  seeds = seeds,
                                  number = 10, 
                                  repeats = 1,
                                  verboseIter = ifelse(is.null(getOption('knitr.in.progress')), TRUE, FALSE))

        gbmGrid <- expand.grid(interaction.depth = c(1, 2, 3, 4, 5, 6),
                               n.trees = seq(300, 600, 50),
                               shrinkage = c(0.1, 0.2, 0.01),
                               n.minobsinnode = c(10))

        fit1 <- train(x = traindata, 
                     y = trainlabels, 
                     method = "gbm",
                     tuneGrid = gbmGrid,
                     trControl = trControl_gbm, 
                     verbose=F)
        ggplot(fit1)
        message("besttune ntrees")
        message(fit1$bestTune$n.trees)
        message("besttune interaction.depth")
        message(fit1$bestTune$interaction.depth)
        message("besttune shrinkage")
        message(fit1$bestTune$shrinkage)
        message("besttune n.minobsinnode")
        message(fit1$bestTune$n.minobsinnode)
        #################################################################
      
        fitControl <- trainControl()
        fit2 <- train(x = traindata, 
                     y = trainlabels,
                     method = "gbm",
                     trControl = fitControl,
                     verbose = FALSE,
                     tuneGrid = data.frame(n.trees = fit1$bestTune$n.trees,
                                           interaction.depth = fit1$bestTune$interaction.depth,
                                           shrinkage = fit1$bestTune$shrinkage,
                                           n.minobsinnode = fit1$bestTune$n.minobsinnode))
              
    
        tmp <- predict(fit2, newdata = testdata, type = "prob")[,2]
        predicted[rows] <- tmp 
        
    }

    current_round_tibble <- tibble(predicted = predicted)
    return_tibble <- cbind(return_tibble, current_round_tibble)
    } # end of outer cv loop
    
    return(return_tibble)
}

# %%
results = cross_validation(data, k_inner_cv = 10, k_outer_cv = 10)
# Out:
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# Aggregating results
# Selecting tuning parameters
# Fitting n.trees = 600, interaction.depth = 5, shrinkage = 0.1, n.minobsinnode = 10 on full training set
# besttune ntrees
# 600
# besttune interaction.depth
# 5
# besttune shrinkage
# 0.1
# besttune n.minobsinnode
# 10
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold01.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold01.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold02.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold02.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold03.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold03.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold04.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold04.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# ...
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold05.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold05.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold06.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold06.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold07.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold07.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold08.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold08.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold09.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold09.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.01, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.10, interaction.depth=6, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=1, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=2, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=3, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=4, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=5, n.minobsinnode=10, n.trees=600
# + Fold10.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# - Fold10.Rep1: shrinkage=0.20, interaction.depth=6, n.minobsinnode=10, n.trees=600
# Aggregating results
# Selecting tuning parameters
# Fitting n.trees = 400, interaction.depth = 3, shrinkage = 0.2, n.minobsinnode = 10 on full training set
# besttune ntrees
# 400
# besttune interaction.depth
# 3
# besttune shrinkage
# 0.2
# besttune n.minobsinnode
# 10

# %%
results <- tibble(results, .name_repair = "unique")
head(results)
# Out:
# New names:
# * predicted -> predicted...2
# * predicted -> predicted...3
# * predicted -> predicted...4
# * predicted -> predicted...5
# * predicted -> predicted...6
# * ...
#   observed predicted...2 predicted...3 predicted...4 predicted...5
# 1 1        0.54204988    0.81775234    0.7493335     9.722374e-01
# 2 1        0.08908208    0.12795114    0.2990033     3.137803e-06
# 3 1        0.99970321    0.99999554    0.9140585     9.955423e-01
# 4 1        0.29688616    0.01320377    0.5544596     8.374015e-06
# 5 1        0.99980051    0.99999972    0.9914569     8.002005e-01
# 6 1        0.88891732    0.99999996    0.8707267     9.998793e-01
#   predicted...6 predicted...7 predicted...8 predicted...9 predicted...10
# 1 0.5862404     0.8033062     4.747543e-01  0.75506742    0.5073172
# 2 0.3372457     0.3665132     8.134898e-05  0.32226034    0.6242168
# 3 0.9957636     0.9948823     8.845371e-01  0.99845595    0.8780857
# 4 0.1153463     0.2552075     3.338093e-01  0.04213021    0.8044820
# 5 0.9975259     0.9917475     9.924879e-01  0.93115894    0.9947831
# 6 0.9928000     0.9999724     9.893733e-01  0.99999676    0.9998807
#   predicted...11
# 1 0.800491642
# 2 0.002669512
# 3 0.826108281
# 4 0.008432817
# 5 0.999996796
# 6 0.799544142

# %%
saveRDS(results, file = snakemake@output[["boosting_output"]])

# %%
rocs <- roc(observed ~ predicted...2 + 
                    predicted...3 + 
                    predicted...4 + 
                    predicted...5 + 
                    predicted...6 +
                    predicted...7 +
                    predicted...8 + 
                    predicted...9 + 
                    predicted...10 + 
                    predicted...11, data = results)
ggroc(rocs)
# Out:
# plot without title

# %%
roc1 <- roc(results$observed, results$predicted...2)
roc2 <- roc(results$observed, results$predicted...3)
roc3 <- roc(results$observed, results$predicted...4)
roc4 <- roc(results$observed, results$predicted...5)
roc5 <- roc(results$observed, results$predicted...6)
roc6 <- roc(results$observed, results$predicted...7)
roc7 <- roc(results$observed, results$predicted...8)
roc8 <- roc(results$observed, results$predicted...9)
roc9 <- roc(results$observed, results$predicted...10)
roc10 <- roc(results$observed, results$predicted...11)

# %%
(roc1$auc)
# Out:
# Area under the curve: 0.8464

# %%
paste("Mean AUC over 10 repetitions of 10-fold CV: ", mean(c(roc1$auc, roc2$auc, roc3$auc, roc4$auc, roc5$auc, roc6$auc, roc7$auc, roc8$auc, roc9$auc, roc10$auc)), sep = "")
# Out:
# [1] "Mean AUC over 10 repetitions of 10-fold CV: 0.850750784401614"

# %%
results_01 <- results %>% mutate(predicted...2_01 = ifelse(predicted...2 > 0.5, 1, 0), 
                                 predicted...3_01 = ifelse(predicted...3 > 0.5, 1, 0), 
                                 predicted...4_01 = ifelse(predicted...4 > 0.5, 1, 0),
                                 predicted...5_01 = ifelse(predicted...5 > 0.5, 1, 0),
                                 predicted...6_01 = ifelse(predicted...6 > 0.5, 1, 0),
                                 predicted...7_01 = ifelse(predicted...7 > 0.5, 1, 0),
                                 predicted...8_01 = ifelse(predicted...8 > 0.5, 1, 0),
                                 predicted...9_01 = ifelse(predicted...9 > 0.5, 1, 0),
                                 predicted...10_01 = ifelse(predicted...10 > 0.5, 1, 0),
                                 predicted...11_01 = ifelse(predicted...11 > 0.5, 1, 0))

# %%
error_rates <- c(mean(results_01$observed != results_01$predicted...2_01), 
                mean(results_01$observed != results_01$predicted...3_01),
               mean(results_01$observed != results_01$predicted...4_01),
               mean(results_01$observed != results_01$predicted...5_01),
               mean(results_01$observed != results_01$predicted...6_01),
               mean(results_01$observed != results_01$predicted...7_01),
               mean(results_01$observed != results_01$predicted...8_01),
               mean(results_01$observed != results_01$predicted...9_01), 
               mean(results_01$observed != results_01$predicted...10_01), 
               mean(results_01$observed != results_01$predicted...11_01))

error_rates

paste("Mean error rate over 10 repetitions of 10-fold CV: ", mean(error_rates), sep = "")
# Out:
#  [1] 0.2051887 0.1910377 0.2004717 0.2028302 0.2099057 0.2169811 0.2193396
#  [8] 0.2051887 0.1957547 0.2099057
# [1] "Mean error rate over 10 repetitions of 10-fold CV: 0.205660377358491"

# %%
accuracies <- c(mean(results_01$observed == results_01$predicted...2_01),
               mean(results_01$observed == results_01$predicted...3_01), 
               mean(results_01$observed == results_01$predicted...4_01),
               mean(results_01$observed == results_01$predicted...5_01),
               mean(results_01$observed == results_01$predicted...6_01),
               mean(results_01$observed == results_01$predicted...7_01),
               mean(results_01$observed == results_01$predicted...8_01),
               mean(results_01$observed == results_01$predicted...9_01), 
               mean(results_01$observed == results_01$predicted...10_01), 
               mean(results_01$observed == results_01$predicted...11_01))

accuracies
paste("Mean accuracy over 10 repetitions of 10-fold CV: ", mean(accuracies), sep = "")
# Out:
#  [1] 0.7948113 0.8089623 0.7995283 0.7971698 0.7900943 0.7830189 0.7806604
#  [8] 0.7948113 0.8042453 0.7900943
# [1] "Mean accuracy over 10 repetitions of 10-fold CV: 0.794339622641509"
