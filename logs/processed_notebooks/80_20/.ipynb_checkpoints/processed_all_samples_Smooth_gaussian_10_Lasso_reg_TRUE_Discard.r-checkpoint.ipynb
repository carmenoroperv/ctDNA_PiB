# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
library(methods)
Snakemake <- setClass(
    "Snakemake",
    slots = c(
        input = "list",
        output = "list",
        params = "list",
        wildcards = "list",
        threads = "numeric",
        log = "list",
        resources = "list",
        config = "list",
        rule = "character",
        bench_iteration = "numeric",
        scriptdir = "character",
        source = "function"
    )
)
snakemake <- Snakemake(
    input = list('data/ATACseq_250kb_bins.txt', 'data/20_80_splits/80_all_samples_normalized_gaussian_smooth_trimmed_CONTROLS.rds', 'data/20_80_splits/20_all_samples_normalized_gaussian_smooth_trimmed_CONTROLS.rds', "input_atac" = 'data/ATACseq_250kb_bins.txt', "input_train_data_trim" = 'data/20_80_splits/80_all_samples_normalized_gaussian_smooth_trimmed_CONTROLS.rds', "input_test_data_trim" = 'data/20_80_splits/20_all_samples_normalized_gaussian_smooth_trimmed_CONTROLS.rds'),
    output = list('data/20_80_experiment_ATAC_predictions/80_20/all_samples_ATAC_pred_lasso_std_TRUE_gaussian_trimmed.rds', 'Trained_models/20_80_experiment_models/80_20/Lasso_models/lasso_std_TRUE_gaussian_trimmed.rds', "output_pred" = 'data/20_80_experiment_ATAC_predictions/80_20/all_samples_ATAC_pred_lasso_std_TRUE_gaussian_trimmed.rds', "output_model" = 'Trained_models/20_80_experiment_models/80_20/Lasso_models/lasso_std_TRUE_gaussian_trimmed.rds'),
    params = list(),
    wildcards = list(),
    threads = 2,
    log = list('logs/processed_notebooks/80_20/processed_all_samples_Smooth_gaussian_10_Lasso_reg_TRUE_Discard.r.ipynb', "notebook" = 'logs/processed_notebooks/80_20/processed_all_samples_Smooth_gaussian_10_Lasso_reg_TRUE_Discard.r.ipynb'),
    resources = list('mem_mb', 'disk_mb', 'tmpdir', 'time', "mem_mb" = 200000, "disk_mb" = 10694, "tmpdir" = '/scratch/56028895', "time" = '5:00:00'),
    config = list(),
    rule = 'all_samples_model_lasso_trimming',
    bench_iteration = as.numeric(NA),
    scriptdir = '/faststorage/project/DELFI1/Workspaces/CarmenAndAnika/20_80_experiments',
    source = function(...){
        wd <- getwd()
        setwd(snakemake@scriptdir)
        source(...)
        setwd(wd)
    }
)
setwd('/faststorage/project/DELFI1/Workspaces/CarmenAndAnika');

######## snakemake preamble end #########

# %% [markdown]
# # Lasso regression on data normalized, smoothed with Gaussian (n = 10) and trimmed (80 to 400)

# %%
library(tidyverse)

library(glmnet)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ purrr   0.3.2
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: Matrix
#
# Attaching package: ‘Matrix’
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loaded glmnet 2.0-16

# %% [markdown]
# ### Read in data and ATAC values, add ATAC values to the dataframe

# %%
#all_samples_gaussian_trimmed_controls <- read.csv("../../../data/all_samples_normalized_gaussian_smooth_trimmed_CONTROLS.csv", nrows=50000)
all_samples_gaussian_trimmed_controls <- readRDS(snakemake@input[["input_train_data_trim"]])

# %%
#ATAC <- read.table("../../../data/ATACseq_250kb_bins.txt", header = FALSE)
ATAC <- read.table(snakemake@input[["input_atac"]], header = FALSE)
colnames(ATAC) <- c("bin", "ATAC_observed")

ATAC$ATAC_observed <- as.character(ATAC$ATAC_observed)
ATAC$ATAC_observed <- as.numeric(ATAC$ATAC_observed)
ATAC$bin <- as.character(ATAC$bin)

all_samples_gaussian_trimmed_controls <- inner_join(all_samples_gaussian_trimmed_controls, ATAC, by="bin")

head(all_samples_gaussian_trimmed_controls)
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
#   sample     bin       X80          X81          X82          X83
# 1 PGDX18242P chr8_268  3.790566e-05 4.622161e-05 4.938088e-05 4.622161e-05
# 2 PGDX18703P chr10_32  0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#
0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 2 1.300328e-04 1.455163e-04 1.516379e-04 1.507298e-04 1.444517e-04 1.328190e-04
# 3 6.534435e-05 5.923853e-05 5.032014e-05 4.672311e-05 3.670505e-05 3.010126e-05
# 4 1.241473e-04 1.148761e-04 1.093465e-04 1.072163e-04 1.031686e-04 9.597954e-05
# 5 9.057796e-05 6.304911e-05 4.295529e-05 2.574697e-05 9.152506e-06 0.000000e+00
# 6 1.902316e-04 1.844542e-04 1.786711e-04 1.768196e-04 1.798893e-04 1.856824e-04
#   X398         X399         X400
# 1 0.000000e+00 0.000000e+00 0.000000e+00
# 2 1.187544e-04 1.100265e-04 1.071638e-04
# 3 2.162800e-05 1.361509e-05 7.509264e-06
# 4 8.844009e-05 8.230856e-05 6.994281e-05
# 5 0.000000e+00 0.000000e+00 0.000000e+00
# 6 1.823412e-04 1.744445e-04 1.580944e-04

# %% [markdown]
# ## Finding the best lambda

# %%
set.seed(0)
#X==predictor
#y==response

y <- ATAC_val %>% as.matrix()
X <- all_samples_gaussian_trimmed_controls %>% as.matrix()

lambdas_to_try <- 10^seq(-15, 0, length.out = 100)
#standardize = FALSE -- range -12, -3
#standardize = TRUE -- range -10, 0


lasso_smooth_cv <- cv.glmnet(X, y, alpha = 1, lambda = lambdas_to_try,
                      standardize = TRUE, nfolds = 10)

#Plotting the MSE and log(lambda)

plot(lasso_smooth_cv)
# Out:
# plot without title

# %%
(lambda_smooth_cv <- lasso_smooth_cv$lambda.min)
# Out:
# [1] 1e-15

# %% [markdown]
# ## Fit the model on all controls

# %%
y <- ATAC_val %>% as.matrix()
X <- all_samples_gaussian_trimmed_controls %>% as.matrix()

fit       <- glmnet(X, y, alpha = 1, lambda = lambda_smooth_cv, standardize = TRUE)
# saving the model
saveRDS(fit, snakemake@output[["output_model"]])

# %% [markdown]
# ## Predict on 20% normalized, smoothed and trimmed controls using the model (fitted on train controls) and save the predictions to the file

# %%
#filename = "../../../data/all_samples_normalized_gaussian_smooth_trimmed_CASES.csv"
#filename = snakemake@input[["input_test_data_trim"]]

test_data = readRDS(snakemake@input[["input_test_data_trim"]])

# %%
head(test_data)
# Out:
#    sample     bin       X80          X81          X82          X83
# 1  PGDX16568P chr10_400 2.656112e-05 2.994814e-05 2.961085e-05 2.929903e-05
# 7  PGDX16568P chr10_404 5.489958e-05 6.520557e-05 7.145319e-05 7.192458e-05
# 8  PGDX16568P chr10_405 2.757195e-05 4.634445e-05 6.291658e-05 7.631448e-05
# 14 PGDX16568P chr10_41  3.149052e-05 3.364291e-05 3.793298e-05 3.750576e-05
# 16 PGDX16568P chr10_412 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 20 PGDX16568P chr10_416 4.992421e-05 3.741455e-05 2.493706e-05 1.165245e-05
#    X84          X85          X86          X87          ... X391
# 1  3.469718e-05 3.917019e-05 4.629696e-05 5.955899e-05 ... 1.797668e-04
# 7  6.601639e-05 5.479535e-05 3.814171e-05 4.259640e-05 ... 1.085559e-04
# 8  8.294342e-05 8.098070e-05 7.702287e-05 6.693922e-05 ... 1.313184e-04
# 14 3.711081e-05 3.750576e-05 3.793298e-05 3.364291e-05 ... 2.728812e-04
# 16 0.000000e+00 6.128687e-06 1.111196e-05 1.765169e-05 ... 1.993618e-04
# 20 6.426788e-06 0.000000e+00 0.000000e+00 6.426788e-06 ... 8.085702e-05
#    X392         X393         X394         X395         X396
# 1  1.753154e-04 1.569416e-04 1.385816e-04 1.166854e-04 9.841735e-05
# 7  1.107729e-04 1.119119e-04 1.064390e-04 1.033041e-04 1.018980e-04
# 8  1.368668e-04 1.395499e-04 1.548882e-04 1.592888e-04 1.644801e-04
# 14 2.536380e-04 2.599412e-04 2.582777e-04 2.614331e-04 2.633253e-04
# 16 2.206129e-04 2.240443e-04 2.207235e-04 2.196415e-04 2.057072e-04
# 20 7.494522e-05 7.486128e-05 7.728631e-05 8.133815e-05 7.877463e-05
#    X397         X398         X399         X400
# 1  8.478873e-05 7.355554e-05 6.464917e-05 7.007278e-05
# 7  1.057282e-04 1.125796e-04 1.134251e-04 1.218507e-04
# 8  1.688678e-04 1.722070e-04 1.633573e-04 1.572449e-04
# 14 2.578892e-04 2.358353e-04 2.031583e-04 1.581519e-04
# 16 1.964937e-04 1.800258e-04 1.685074e-04 1.649003e-04
# 20 8.210824e-05 8.125589e-05 9.212034e-05 1.049918e-04

# %%
test_data_samples_bin_rm <- test_data %>% select(-c("sample", "bin")) %>% as.matrix()
tmp <- as.vector(predict(fit, s=lambda_smooth_cv, test_data_samples_bin_rm))

# %%
pred_tibble <- tibble(sample = test_data$sample, bin = test_data$bin)
pred_tibble <- inner_join(pred_tibble, ATAC, by="bin")
pred_tibble <- pred_tibble %>% mutate(ATAC_predicted = tmp)

# %%
ggplot(pred_tibble, aes(x = ATAC_observed, y = ATAC_predicted)) + 
    geom_point(size = 0.5) + 
    geom_smooth(method = "lm", formula = y~x)
# Out:
# plot without title

# %%
cor(pred_tibble$ATAC_observed, pred_tibble$ATAC_predicted)
# Out:
# [1] 0.5451225

# %%
ae    <- abs(pred_tibble$ATAC_observed - pred_tibble$ATAC_predicted)
(mae   <- mean(ae))
# Out:
# [1] 0.08148854

# %%
se    <- (pred_tibble$ATAC_observed - pred_tibble$ATAC_predicted)^2
mse   <- mean(se)
(rmse <- sqrt(mse))
# Out:
# [1] 0.1049054

# %%
saveRDS(pred_tibble, file = snakemake@output[["output_pred"]])
