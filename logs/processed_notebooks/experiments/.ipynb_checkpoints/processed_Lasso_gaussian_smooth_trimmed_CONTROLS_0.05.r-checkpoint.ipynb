# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
library(methods)
Snakemake <- setClass(
    "Snakemake",
    slots = c(
        input = "list",
        output = "list",
        params = "list",
        wildcards = "list",
        threads = "numeric",
        log = "list",
        resources = "list",
        config = "list",
        rule = "character",
        bench_iteration = "numeric",
        scriptdir = "character",
        source = "function"
    )
)
snakemake <- Snakemake(
    input = list('data/experiment_ATAC_predictions/traindata_splits_diff_percentages/gaussian_smooth_trimmed_CONTROLS_split_0.05.rds', 'data/20_80_splits_group_by_ind/20_all_samples_normalized_gaussian_smooth_trimmed_CONTROLS.rds', 'data/ATACseq_250kb_bins.txt', "input_train" = 'data/experiment_ATAC_predictions/traindata_splits_diff_percentages/gaussian_smooth_trimmed_CONTROLS_split_0.05.rds', "input_test" = 'data/20_80_splits_group_by_ind/20_all_samples_normalized_gaussian_smooth_trimmed_CONTROLS.rds', "input_atac" = 'data/ATACseq_250kb_bins.txt'),
    output = list('data/experiment_ATAC_predictions/ATAC_predictions/ATAC_pred_lasso_experiment_gaussian_smooth_trimmed_CONTROLS_0.05.rds', 'Trained_models/experiment_models/Lasso_models/lasso_gaussian_smooth_trimmed_CONTROLS_0.05.rds', "output_pred" = 'data/experiment_ATAC_predictions/ATAC_predictions/ATAC_pred_lasso_experiment_gaussian_smooth_trimmed_CONTROLS_0.05.rds', "output_model" = 'Trained_models/experiment_models/Lasso_models/lasso_gaussian_smooth_trimmed_CONTROLS_0.05.rds'),
    params = list(),
    wildcards = list('gaussian_smooth_trimmed_CONTROLS', '0.05', "suffix" = 'gaussian_smooth_trimmed_CONTROLS', "percentage" = '0.05'),
    threads = 5,
    log = list('logs/processed_notebooks/experiments/processed_Lasso_gaussian_smooth_trimmed_CONTROLS_0.05.r.ipynb', "notebook" = 'logs/processed_notebooks/experiments/processed_Lasso_gaussian_smooth_trimmed_CONTROLS_0.05.r.ipynb'),
    resources = list('mem_mb', 'disk_mb', 'tmpdir', 'time', "mem_mb" = 200000, "disk_mb" = 2586, "tmpdir" = '/scratch/56505551', "time" = '10:00:00'),
    config = list(),
    rule = 'ATAC_predictions',
    bench_iteration = as.numeric(NA),
    scriptdir = '/faststorage/project/DELFI1/Workspaces/CarmenAndAnika/20_80_experiments',
    source = function(...){
        wd <- getwd()
        setwd(snakemake@scriptdir)
        source(...)
        setwd(wd)
    }
)
setwd('/faststorage/project/DELFI1/Workspaces/CarmenAndAnika');

######## snakemake preamble end #########

# %% [markdown]
# # Lasso regression

# %%
library(tidyverse)
library(glmnet)

install.packages('glmnetUtils')
library(glmnetUtils)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: Matrix
#
# Attaching package: ‘Matrix’
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
# Loading required package: foreach
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loaded glmnet 2.0-16
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
#
# Attaching package: ‘glmnetUtils’
#
# The following objects are masked from ‘package:glmnet’:
#
#     cv.glmnet, glmnet

# %% [markdown]
# ### Read in data and ATAC values, add ATAC values to the dataframe

# %%
#all_samples_controls <- readRDS("../data/experiment_ATAC_predictions/CONTROLS_split_0.05.rds")
all_samples_controls <- readRDS(snakemake@input[["input_train"]])
head(all_samples_controls)
# Out:
#   sample     bin       X80          X81          X82          X83
# 1 PGDX16594P chr10_400 1.731382e-05 2.111222e-05 2.687447e-05 2.894343e-05
# 2 PGDX16594P chr10_40  1.039322e-05 5.732274e-06 0.000000e+00 0.000000e+00
# 3 PGDX16594P chr10_4   1.554726e-05 2.703628e-05 3.617256e-05 4.913410e-05
# 4 PGDX16594P chr10_401 3.551055e-05 4.586048e-05 5.727087e-05 6.146233e-05
# 5 PGDX16594P chr10_402 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 6 PGDX16594P chr10_403 5.588174e-05 4.917422e-05 3.807644e-05 2.594143e-05
#   X84          X85          X86          X87          ... X391
# 1 2.975393e-05 4.271160e-05 5.243704e-05 6.419482e-05 ... 1.693806e-04
# 2 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 2.083245e-04
# 3 6.320884e-05 7.335807e-05 8.092159e-05 1.057883e-04 ... 1.253004e-04
# 4 6.070743e-05 5.617414e-05 4.939018e-05 4.142032e-05 ... 1.518637e-04
# 5 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 7.511575e-05
# 6 1.554904e-05 5.527355e-06 0.000000e+00 0.000000e+00 ... 8.653690e-05
#   X392         X393         X394         X395         X396         X397
# 1 1.607356e-04 1.578594e-04 1.610285e-04 1.644625e-04 1.661919e-04 1.581827e-04
# 2 2.148257e-04 2.167452e-04 2.175715e-04 2.055830e-04 1.796472e-04 1.591388e-04
# 3 1.351960e-04 1.527962e-04 1.654107e-04 1.778446e-04 1.874111e-04 1.879938e-04
# 4 1.599271e-04 1.549908e-04 1.456160e-04 1.307573e-04 1.161901e-04 1.008081e-04
# 5 7.914911e-05 8.621680e-05 8.805298e-05 8.610716e-05 1.043916e-04 1.148165e-04
# 6 6.988408e-05 6.883565e-05 6.814148e-05 7.614869e-05 7.803842e-05 8.289928e-05
#   X398         X399         X400
# 1 1.422306e-04 1.161667e-04 8.845129e-05
# 2 1.338941e-04 1.067188e-04 8.936501e-05
# 3 1.978450e-04 1.987559e-04 1.944794e-04
# 4 9.390133e-05 9.133505e-05 8.180990e-05
# 5 1.301752e-04 1.444527e-04 1.548471e-04
# 6 8.356578e-05 7.511566e-05 6.401787e-05

# %%
#ATAC <- read.table("../../../data/ATACseq_250kb_bins.txt", header = FALSE)
ATAC <- read.table(snakemake@input[["input_atac"]], header = FALSE)

colnames(ATAC) <- c("bin", "ATAC_observed")
head(ATAC)

ATAC$ATAC_observed <- as.character(ATAC$ATAC_observed)
ATAC$ATAC_observed <- as.numeric(ATAC$ATAC_observed)
ATAC$bin <- as.character(ATAC$bin)

all_samples_ATAC_controls <- inner_join(all_samples_controls, ATAC, by="bin")

head(all_samples_ATAC_controls)
# Out:
#   bin       ATAC_observed
# 1 chr1_0    0.05376791
# 2 chr10_0   0.29698782
# 3 chr10_1   0.40893151
# 4 chr10_10  0.30582283
# 5 chr10_100 0.59316570
# 6 chr10_101 0.47641373
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”Warning message:
# “Column `bin` joining factor and character vector, coercing into character vector”
#   sample     bin       X80          X81          X82          X83
# 1 PGDX16594P chr10_400 1.731382e-05 2.111222e-05 2.687447e-05 2.894343e-05
# 2 PGDX16594P chr10_40  1.039322e-05 5.732274e-06 0.000000e+00 0.000000e+00
# 3 PGDX16594P chr10_4   1.554726e-05 2.703628e-05 3.617256e-05 4.913410e-05
# 4 PGDX16594P chr10_401 3.551055e-05 4.586048e-05 5.727087e-05 6.146233e-05
# 5 PGDX16594P chr10_402 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 6 PGDX16594P chr10_403 5.588174e-05 4.917422e-05 3.807644e-05 2.594143e-05
#   X84          X85          X86          X87          ... X392
# 1 2.975393e-05 4.271160e-05 5.243704e-05 6.419482e-05 ... 1.607356e-04
# 2 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 2.148257e-04
# 3 6.320884e-05 7.335807e-05 8.092159e-05 1.057883e-04 ... 1.351960e-04
# 4 6.070743e-05 5.617414e-05 4.939018e-05 4.142032e-05 ... 1.599271e-04
# 5 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 7.914911e-05
# 6 1.554904e-05 5.527355e-06 0.000000e+00 0.000000e+00 ... 6.988408e-05
#   X393         X394         X395         X396         X397         X398
# 1 1.578594e-04 1.610285e-04 1.644625e-04 1.661919e-04 1.581827e-04 1.422306e-04
# 2 2.167452e-04 2.175715e-04 2.055830e-04 1.796472e-04 1.591388e-04 1.338941e-04
# 3 1.527962e-04 1.654107e-04 1.778446e-04 1.874111e-04 1.879938e-04 1.978450e-04
# 4 1.549908e-04 1.456160e-04 1.307573e-04 1.161901e-04 1.008081e-04 9.390133e-05
# 5 8.621680e-05 8.805298e-05 8.610716e-05 1.043916e-04 1.148165e-04 1.301752e-04
# 6 6.883565e-05 6.814148e-05 7.614869e-05 7.803842e-05 8.289928e-05 8.356578e-05
#   X399         X400         ATAC_observed
# 1 1.161667e-04 8.845129e-05 0.5866651
# 2 1.067188e-04 8.936501e-05 0.1996134
# 3 1.987559e-04 1.944794e-04 0.5968816
# 4 9.133505e-05 8.180990e-05 0.2905764
# 5 1.444527e-04 1.548471e-04 0.2319729
# 6 7.511566e-05 6.401787e-05 0.2262170

# %%
ATAC_val <- all_samples_ATAC_controls %>% select(ATAC_observed)
controls_predictions <- all_samples_ATAC_controls %>% select(sample, bin)
all_samples_ATAC_controls = all_samples_ATAC_controls %>% select(-c(ATAC_observed, sample, bin))

head(all_samples_ATAC_controls)
head(ATAC_val)
# Out:
#   X80          X81          X82          X83          X84          X85
# 1 1.731382e-05 2.111222e-05 2.687447e-05 2.894343e-05 2.975393e-05 4.271160e-05
# 2 1.039322e-05 5.732274e-06 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 3 1.554726e-05 2.703628e-05 3.617256e-05 4.913410e-05 6.320884e-05 7.335807e-05
# 4 3.551055e-05 4.586048e-05 5.727087e-05 6.146233e-05 6.070743e-05 5.617414e-05
# 5 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 6 5.588174e-05 4.917422e-05 3.807644e-05 2.594143e-05 1.554904e-05 5.527355e-06
#   X86          X87          X88          X89          ... X391
# 1 5.243704e-05 6.419482e-05 8.601134e-05 1.041441e-04 ... 1.693806e-04
# 2 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 2.083245e-04
# 3 8.092159e-05 1.057883e-04 1.207592e-04 1.323105e-04 ... 1.253004e-04
# 4 4.939018e-05 4.142032e-05 3.035176e-05 2.066359e-05 ... 1.518637e-04
# 5 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 7.511575e-05
# 6 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 8.653690e-05
#   X392         X393         X394         X395         X396         X397
# 1 1.607356e-04 1.578594e-04 1.610285e-04 1.644625e-04 1.661919e-04 1.581827e-04
# 2 2.148257e-04 2.167452e-04 2.175715e-04 2.055830e-04 1.796472e-04 1.591388e-04
# 3 1.351960e-04 1.527962e-04 1.654107e-04 1.778446e-04 1.874111e-04 1.879938e-04
# 4 1.599271e-04 1.549908e-04 1.456160e-04 1.307573e-04 1.161901e-04 1.008081e-04
# 5 7.914911e-05 8.621680e-05 8.805298e-05 8.610716e-05 1.043916e-04 1.148165e-04
# 6 6.988408e-05 6.883565e-05 6.814148e-05 7.614869e-05 7.803842e-05 8.289928e-05
#   X398         X399         X400
# 1 1.422306e-04 1.161667e-04 8.845129e-05
# 2 1.338941e-04 1.067188e-04 8.936501e-05
# 3 1.978450e-04 1.987559e-04 1.944794e-04
# 4 9.390133e-05 9.133505e-05 8.180990e-05
# 5 1.301752e-04 1.444527e-04 1.548471e-04
# 6 8.356578e-05 7.511566e-05 6.401787e-05
#   ATAC_observed
# 1 0.5866651
# 2 0.1996134
# 3 0.5968816
# 4 0.2905764
# 5 0.2319729
# 6 0.2262170

# %% [markdown]
# # Lasso regression

# %% [markdown]
# ## Cross validation to find the best lambda and alpha

# %%
get_cvm <- function(model) {
   index <- match(model$lambda.min, model$lambda)
  model$cvm[index]
}

# %%
set.seed(0)

y <- ATAC_val %>% as.matrix()
X <- all_samples_ATAC_controls %>% as.matrix()

######### finding the best alpha #########
set.seed(0)
lasso_cva <- glmnetUtils::cva.glmnet(X, y, nfolds = 10)
enet_performance <- data.frame(alpha = lasso_cva$alpha)
models <- lasso_cva$modlist
enet_performance$cvm <- vapply(models, get_cvm, numeric(1))

minix <- which.min(enet_performance$cvm)
best_alpha <- lasso_cva$alpha[minix]
###########################################

######### finding the best lambda #########
set.seed(0)
lasso_cv <- glmnet::cv.glmnet(X, y, alpha = best_alpha,
                      standardize = TRUE, nfolds = 10)

plot(lasso_cv)
###########################################
# Out:
# plot without title

# %%
(lambda_cv <- lasso_cv$lambda.min)
# Out:
# [1] 4.928086e-05

# %% [markdown]
# ## Fit the model on all traindata controls

# %%
y <- ATAC_val %>% as.matrix()
X <- all_samples_ATAC_controls %>% as.matrix()

fit       <- glmnet::glmnet(X, y, alpha = best_alpha, lambda = lambda_cv, standardize = TRUE)
# saving the model
saveRDS(fit, snakemake@output[["output_model"]])

# %% [markdown]
# ## Predict on normalized 20% of controls using the model (fitted on train controls) and save the predictions to file

# %%
#filename = "../../../data/all_samples_normalized_CASES.csv"
#test_data = readRDS("../../data/20_80_splits/20_all_samples_normalized_CONTROLS.rds")

test_data = readRDS(snakemake@input[["input_test"]])

# %%
head(test_data)
# Out:
#   sample     bin       X80          X81          X82          X83
# 1 PGDX16571P chr10_400 3.012834e-05 3.218762e-05 3.012834e-05 2.470780e-05
# 2 PGDX16571P chr10_40  2.259093e-05 3.144145e-05 3.833924e-05 4.095974e-05
# 3 PGDX16571P chr10_4   0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 4 PGDX16571P chr10_401 5.645446e-05 6.883975e-05 7.354497e-05 6.883975e-05
# 5 PGDX16571P chr10_402 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 6 PGDX16571P chr10_403 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#   X84          X85          X86          X87          ... X391
# 1 1.775275e-05 1.733935e-05 1.733935e-05 1.775275e-05 ... 9.494004e-05
# 2 3.833924e-05 3.144145e-05 2.259093e-05 2.206486e-05 ... 8.494775e-05
# 3 0.000000e+00 0.000000e+00 0.000000e+00 6.878457e-06 ... 6.031131e-05
# 4 5.645446e-05 4.056297e-05 3.961840e-05 3.961840e-05 ... 4.803643e-05
# 5 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 7.805601e-05
# 6 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00 ... 2.157497e-04
#   X392         X393         X394         X395         X396         X397
# 1 8.581908e-05 6.847973e-05 5.483614e-05 4.246055e-05 2.892833e-05 1.733935e-05
# 2 6.777278e-05 5.988398e-05 5.402643e-05 4.095974e-05 3.833924e-05 3.144145e-05
# 3 7.596375e-05 9.393299e-05 1.104149e-04 1.193371e-04 1.233476e-04 1.215056e-04
# 4 5.464648e-05 6.652956e-05 8.202460e-05 9.322694e-05 1.103014e-04 1.145396e-04
# 5 1.077642e-04 1.346574e-04 1.572478e-04 1.780925e-04 1.831648e-04 1.701923e-04
# 6 2.061356e-04 1.790666e-04 1.599142e-04 1.419695e-04 1.245615e-04 1.059864e-04
#   X398         X399         X400
# 1 6.163774e-06 0.000000e+00 0.000000e+00
# 2 2.259093e-05 1.422127e-05 7.843594e-06
# 3 1.095854e-04 9.623104e-05 7.366570e-05
# 4 1.094027e-04 9.744913e-05 8.202460e-05
# 5 1.421209e-04 1.103068e-04 8.356500e-05
# 6 8.870360e-05 6.792235e-05 5.704793e-05

# %%
test_data_samples_bin_rm <- test_data %>% select(-c("sample", "bin")) %>% as.matrix()
tmp <- as.vector(predict(fit, s=lambda_cv, test_data_samples_bin_rm))

# %%
pred_tibble <- tibble(sample = test_data$sample, bin = test_data$bin)
pred_tibble <- inner_join(pred_tibble, ATAC, by="bin")
pred_tibble <- pred_tibble %>% mutate(ATAC_predicted = tmp)
# Out:
# Warning message:
# “Column `bin` joining factor and character vector, coercing into character vector”

# %%
ggplot(pred_tibble, aes(x = ATAC_observed, y = ATAC_predicted)) + 
    geom_point(size = 0.5) + 
    geom_smooth(method = "lm", formula = y~x)
# Out:
# plot without title

# %%
cor(pred_tibble$ATAC_observed, pred_tibble$ATAC_predicted)
# Out:
# [1] 0.5347511

# %%
ae    <- abs(pred_tibble$ATAC_observed - pred_tibble$ATAC_predicted)
(mae   <- mean(ae))
# Out:
# [1] 0.08261804

# %%
se    <- (pred_tibble$ATAC_observed - pred_tibble$ATAC_predicted)^2
mse   <- mean(se)
(rmse <- sqrt(mse))
# Out:
# [1] 0.1062725

# %%
saveRDS(pred_tibble, file = snakemake@output[["output_pred"]])
