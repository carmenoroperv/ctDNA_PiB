# %% [markdown]
# # Random forest

# %%
library(tidyverse)
library(randomForest)
library(caret)
#install.packages("ranger")
library(ranger)
#install.packages("e1071")
library(e1071)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1     ✔ purrr   0.3.2
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: ‘randomForest’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
# Loading required package: lattice
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
#
# Attaching package: ‘ranger’
#
# The following object is masked from ‘package:randomForest’:
#
#     importance

# %% [markdown]
# ## Reading in the data

# %%
sum_control_ATAC_bin_rm = read.csv("data/sum_control_normalized_ATAC_bin_rm.csv")
sum_control_ATAC = read.csv("data/sum_control_normalized_ATAC.csv")

ATAC_val <- sum_control_ATAC_bin_rm$ATAC_val
sum_control_ATAC_bin_rm <- sum_control_ATAC_bin_rm %>% select(-ATAC_val)

head(sum_control_ATAC_bin_rm)
# Out:
#   X30          X31          X32          X33          X34          X35
# 1 8.699646e-07 3.479859e-06 2.609894e-06 0.000000e+00 8.699646e-07 8.699646e-07
# 2 8.313727e-07 8.313727e-07 0.000000e+00 8.313727e-07 1.662745e-06 8.313727e-07
# 3 8.705774e-07 1.741155e-06 8.705774e-07 8.705774e-07 0.000000e+00 0.000000e+00
# 4 0.000000e+00 1.700685e-06 0.000000e+00 8.503423e-07 8.503423e-07 1.700685e-06
# 5 0.000000e+00 9.416577e-07 0.000000e+00 0.000000e+00 9.416577e-07 0.000000e+00
# 6 0.000000e+00 0.000000e+00 0.000000e+00 4.221123e-06 1.688449e-06 1.688449e-06
#   X36          X37          X38          X39          ... X691 X692 X693 X694
# 1 1.739929e-06 1.739929e-06 0.000000e+00 2.609894e-06 ... 0    0    0    0
# 2 8.313727e-07 5.819609e-06 3.325491e-06 3.325491e-06 ... 0    0    0    0
# 3 2.611732e-06 3.482309e-06 0.000000e+00 8.705774e-07 ... 0    0    0    0
# 4 8.503423e-07 0.000000e+00 8.503423e-07 8.503423e-07 ... 0    0    0    0
# 5 9.416577e-07 0.000000e+00 2.824973e-06 0.000000e+00 ... 0    0    0    0
# 6 8.442245e-07 0.000000e+00 2.532674e-06 0.000000e+00 ... 0    0    0    0
#   X695 X696 X697 X698 X699 X700
# 1 0    0    0    0    0    0.000000e+00
# 2 0    0    0    0    0    0.000000e+00
# 3 0    0    0    0    0    8.705774e-07
# 4 0    0    0    0    0    0.000000e+00
# 5 0    0    0    0    0    0.000000e+00
# 6 0    0    0    0    0    0.000000e+00

# %%
head(ATAC_val)
str(ATAC_val)
# Out:
# [1] 0.5931657 0.4089315 0.3058228 0.4764137 0.2862775 0.3169988
#  num [1:10303] 0.593 0.409 0.306 0.476 0.286 ...

# %% [markdown]
# ## Random forest

# %%
set.seed(0)

x <- getModelInfo(model = "ranger")[[1]]
x$parameters
x$label
x$type
# Out:
#   parameter     class     label
# 1 mtry          numeric   #Randomly Selected Predictors
# 2 splitrule     character Splitting Rule
# 3 min.node.size numeric   Minimal Node Size
# [1] "Random Forest"
# [1] "Classification" "Regression"

# %%
training_x <- sum_control_ATAC_bin_rm %>% as.data.frame()
training_y <- ATAC_val

trControl <- trainControl(method = "repeatedcv", number = 10, repeats = 1, verboseIter = T)
  
fit <- train(x = training_x, 
             y = training_y, 
             method = "ranger",
             trControl = trControl
    )

# %%
print(fit)
ggplot(fit)

# %%
mean(fit$resample$RMSE)

# %%
# get the predicted values
res_rf_pred <- tibble(observed = ATAC_val, predicted =

# %%
ggplot(res_rf_pred, aes(x = observed, y = predicted)) + 
    geom_point(size = 0.5) + 
    geom_smooth(method = "lm", formula = y~x)

# %%
cor(res_rf_pred$observed, res_rf_pred$predicted)

# %% [markdown]
# ### Random forest with the ranger package

# %%
sum_control_ATAC_bin_rm = read.csv("data/sum_control_normalized_ATAC_bin_rm.csv")

# %%
set.seed(0)

(fit = randomForest(ATAC_val~., data = sum_control_ATAC_bin_rm, ntree = 500, do.trace = T))
# Out:
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#    1 |  0.01645   105.07 |
#    2 |  0.01559    99.58 |
#    3 |  0.01474    94.15 |
#    4 |  0.01413    90.24 |
#    5 |  0.01349    86.22 |
#    6 |  0.01295    82.70 |
#    7 |  0.01233    78.80 |
#    8 |  0.01169    74.65 |
#    9 |  0.01134    72.43 |
#   10 |  0.01102    70.38 |
#   11 |  0.01078    68.85 |
#   12 |  0.01049    67.03 |
#   13 |  0.01025    65.47 |
#   14 |  0.01005    64.20 |
#   15 |  0.00983    62.80 |
#   16 | 0.009658    61.70 |
#   17 | 0.009531    60.89 |
#   18 |  0.00945    60.37 |
#   19 | 0.009355    59.76 |
#   20 | 0.009249    59.09 |
#   21 | 0.009179    58.64 |
#   22 | 0.009135    58.36 |
#   23 | 0.009087    58.06 |
#   24 | 0.009025    57.66 |
#   25 | 0.008993    57.45 |
#   26 | 0.008952    57.19 |
#   27 | 0.008904    56.89 |
#   28 |  0.00885    56.54 |
#   29 | 0.008806    56.26 |
#   30 | 0.008772    56.04 |
#   31 | 0.008735    55.81 |
#   32 | 0.008701    55.58 |
#   33 |  0.00869    55.52 |
#   34 | 0.008669    55.38 |
#   35 | 0.008651    55.27 |
#   36 | 0.008618    55.06 |
#   37 | 0.008595    54.91 |
#   38 | 0.008577    54.80 |
#   39 | 0.008552    54.64 |
#   40 | 0.008536    54.53 |
#   41 | 0.008524    54.46 |
#   42 | 0.008522    54.44 |
#   43 | 0.008506    54.34 |
#   44 | 0.008489    54.24 |
#   45 | 0.008464    54.07 |
#   46 |  0.00845    53.99 |
#   47 | 0.008439    53.92 |
#   48 | 0.008434    53.88 |
#   49 | 0.008421    53.80 |
#   50 | 0.008421    53.80 |
#   51 |   0.0084    53.67 |
#   52 | 0.008392    53.62 |
#   53 | 0.008396    53.64 |
#   54 | 0.008389    53.59 |
#   55 | 0.008374    53.50 |
#   56 | 0.008368    53.46 |
#   57 | 0.008359    53.41 |
#   58 |  0.00835    53.35 |
#   59 | 0.008344    53.31 |
#   60 | 0.008329    53.21 |
#   61 | 0.008331    53.22 |
#   62 | 0.008325    53.18 |
#   63 | 0.008321    53.16 |
#   64 | 0.008317    53.13 |
#   65 | 0.008307    53.07 |
#   66 | 0.008304    53.05 |
#   67 | 0.008293    52.98 |
#   68 | 0.008292    52.97 |
#   69 | 0.008287    52.94 |
#   70 | 0.008277    52.88 |
#   71 | 0.008274    52.86 |
#   72 | 0.008275    52.87 |
#   73 | 0.008271    52.84 |
#   74 | 0.008271    52.84 |
#   75 |  0.00826    52.77 |
#   76 | 0.008253    52.72 |
#   77 | 0.008252    52.72 |
#   78 | 0.008249    52.70 |
#   79 | 0.008245    52.68 |
#   80 | 0.008242    52.66 |
#   81 | 0.008228    52.57 |
#   82 | 0.008218    52.50 |
#   83 | 0.008216    52.49 |
#   84 | 0.008215    52.48 |
#   85 | 0.008214    52.48 |
#   86 | 0.008213    52.47 |
#   87 | 0.008207    52.43 |
#   88 | 0.008199    52.38 |
#   89 | 0.008202    52.40 |
#   90 |   0.0082    52.39 |
#   91 | 0.008198    52.37 |
#   92 | 0.008196    52.36 |
#   93 | 0.008189    52.31 |
#   94 | 0.008184    52.28 |
#   95 | 0.008178    52.25 |
#   96 | 0.008175    52.23 |
#   97 | 0.008165    52.16 |
#   98 | 0.008165    52.16 |
#   99 | 0.008162    52.14 |
#  100 | 0.008164    52.15 |
#  101 | 0.008159    52.13 |
#  102 | 0.008157    52.11 |
#  103 | 0.008154    52.09 |
#  104 | 0.008153    52.09 |
#  105 | 0.008152    52.08 |
#  106 | 0.008152    52.08 |
#  107 | 0.008154    52.09 |
#  108 | 0.008147    52.05 |
#  109 |  0.00815    52.07 |
#  110 | 0.008157    52.11 |
#  111 | 0.008157    52.11 |
#  112 | 0.008151    52.07 |
#  113 | 0.008149    52.06 |
#  114 | 0.008152    52.08 |
#  115 | 0.008151    52.07 |
#  116 | 0.008147    52.05 |
#  117 | 0.008147    52.05 |
#  118 | 0.008145    52.03 |
#  119 | 0.008144    52.03 |
#  120 | 0.008145    52.04 |
#  121 | 0.008146    52.04 |
#  122 | 0.008141    52.01 |
#  123 | 0.008137    51.98 |
#  124 | 0.008136    51.98 |
#  125 | 0.008134    51.97 |
#  126 | 0.008129    51.93 |
#  127 | 0.008129    51.93 |
#  128 |  0.00813    51.94 |
#  129 | 0.008123    51.89 |
#  130 | 0.008121    51.89 |
#  131 | 0.008118    51.86 |
#  132 | 0.008112    51.83 |
#  133 | 0.008111    51.82 |
#  134 | 0.008108    51.80 |
#  135 | 0.008108    51.80 |
#  136 | 0.008106    51.79 |
#  137 | 0.008104    51.77 |
#  138 | 0.008101    51.76 |
#  139 | 0.008098    51.73 |
#  140 |  0.00809    51.69 |
#  141 |  0.00809    51.68 |
#  142 |  0.00809    51.68 |
#  143 | 0.008088    51.67 |
#  144 | 0.008085    51.65 |
#  145 |  0.00808    51.62 |
#  146 | 0.008079    51.62 |
#  147 | 0.008079    51.61 |
#  148 | 0.008076    51.59 |
#  149 | 0.008078    51.61 |
#  150 | 0.008074    51.59 |
#  151 | 0.008077    51.60 |
#  152 | 0.008075    51.59 |
#  153 | 0.008078    51.61 |
#  154 | 0.008081    51.62 |
#  155 | 0.008084    51.65 |
#  156 | 0.008086    51.66 |
#  157 |  0.00809    51.68 |
#  158 | 0.008089    51.68 |
#  159 | 0.008089    51.68 |
#  160 | 0.008092    51.69 |
#  161 | 0.008091    51.69 |
#  162 | 0.008089    51.68 |
#  163 | 0.008086    51.66 |
#  164 | 0.008084    51.65 |
#  165 | 0.008083    51.64 |
#  166 | 0.008082    51.63 |
#  167 | 0.008083    51.64 |
#  168 | 0.008085    51.65 |
#  169 | 0.008084    51.65 |
#  170 | 0.008083    51.64 |
#  171 | 0.008079    51.62 |
#  172 | 0.008081    51.63 |
#  173 |  0.00808    51.62 |
#  174 | 0.008079    51.61 |
#  175 |  0.00808    51.62 |
#  176 | 0.008077    51.60 |
#  177 | 0.008077    51.60 |
#  178 | 0.008076    51.59 |
#  179 | 0.008077    51.60 |
#  180 | 0.008074    51.58 |
#  181 | 0.008076    51.59 |
#  182 | 0.008076    51.59 |
#  183 | 0.008076    51.60 |
#  184 | 0.008077    51.60 |
#  185 | 0.008079    51.61 |
#  186 | 0.008078    51.61 |
#  187 | 0.008079    51.62 |
#  188 |  0.00808    51.62 |
#  189 | 0.008079    51.62 |
#  190 | 0.008081    51.63 |
#  191 | 0.008081    51.63 |
#  192 | 0.008083    51.64 |
#  193 | 0.008084    51.64 |
#  194 | 0.008085    51.65 |
#  195 | 0.008083    51.64 |
#  196 | 0.008082    51.64 |
#  197 | 0.008079    51.61 |
#  198 | 0.008079    51.62 |
#  199 | 0.008078    51.61 |
#  200 | 0.008076    51.60 |
#  201 | 0.008075    51.59 |
#  202 | 0.008075    51.59 |
#  203 | 0.008076    51.60 |
#  204 | 0.008076    51.60 |
#  205 | 0.008076    51.59 |
#  206 | 0.008074    51.58 |
#  207 | 0.008074    51.58 |
#  208 | 0.008074    51.58 |
#  209 | 0.008075    51.59 |
#  210 | 0.008075    51.59 |
#  211 | 0.008076    51.60 |
#  212 | 0.008075    51.59 |
#  213 | 0.008074    51.58 |
#  214 | 0.008072    51.57 |
#  215 | 0.008074    51.58 |
#  216 | 0.008074    51.58 |
#  217 | 0.008076    51.59 |
#  218 | 0.008075    51.59 |
#  219 | 0.008076    51.59 |
#  220 | 0.008076    51.59 |
#  221 | 0.008077    51.60 |
#  222 | 0.008073    51.58 |
#  223 | 0.008073    51.58 |
#  224 | 0.008074    51.58 |
#  225 |  0.00807    51.56 |
#  226 | 0.008069    51.55 |
#  227 | 0.008067    51.54 |
#  228 | 0.008066    51.53 |
#  229 | 0.008065    51.52 |
#  230 | 0.008063    51.51 |
#  231 | 0.008064    51.52 |
#  232 | 0.008063    51.51 |
#  233 | 0.008063    51.51 |
#  234 | 0.008062    51.51 |
#  235 | 0.008061    51.50 |
#  236 | 0.008061    51.50 |
#  237 | 0.008059    51.49 |
#  238 | 0.008059    51.49 |
#  239 |  0.00806    51.50 |
#  240 |  0.00806    51.50 |
#  241 | 0.008059    51.49 |
#  242 | 0.008058    51.48 |
#  243 | 0.008059    51.48 |
#  244 | 0.008057    51.48 |
#  245 | 0.008056    51.47 |
#  246 | 0.008055    51.46 |
#  247 | 0.008053    51.45 |
#  248 | 0.008052    51.44 |
#  249 | 0.008052    51.44 |
#  250 | 0.008052    51.44 |
#  251 | 0.008052    51.44 |
#  252 | 0.008051    51.43 |
#  253 | 0.008052    51.44 |
#  254 | 0.008051    51.44 |
#  255 |  0.00805    51.43 |
#  256 | 0.008051    51.44 |
#  257 | 0.008049    51.42 |
#  258 | 0.008048    51.42 |
#  259 | 0.008049    51.43 |
#  260 |  0.00805    51.43 |
#  261 | 0.008051    51.43 |
#  262 |  0.00805    51.43 |
#  263 | 0.008049    51.42 |
#  264 | 0.008049    51.42 |
#  265 |  0.00805    51.43 |
#  266 | 0.008049    51.42 |
#  267 | 0.008047    51.41 |
#  268 | 0.008048    51.41 |
#  269 | 0.008049    51.42 |
#  270 | 0.008045    51.40 |
#  271 | 0.008045    51.39 |
#  272 | 0.008043    51.38 |
#  273 | 0.008042    51.38 |
#  274 | 0.008041    51.37 |
#  275 |  0.00804    51.37 |
#  276 |  0.00804    51.37 |
#  277 | 0.008041    51.37 |
#  278 | 0.008041    51.37 |
#  279 | 0.008039    51.36 |
#  280 | 0.008039    51.36 |
#  281 | 0.008039    51.36 |
#  282 | 0.008038    51.35 |
#  283 | 0.008038    51.35 |
#  284 | 0.008038    51.35 |
#  285 | 0.008039    51.36 |
#  286 | 0.008039    51.36 |
#  287 |  0.00804    51.36 |
#  288 | 0.008038    51.35 |
#  289 | 0.008039    51.36 |
#  290 | 0.008039    51.36 |
#  291 | 0.008038    51.35 |
#  292 | 0.008038    51.35 |
#  293 | 0.008038    51.35 |
#  294 | 0.008036    51.34 |
#  295 | 0.008036    51.34 |
#  296 | 0.008036    51.34 |
#  297 | 0.008036    51.34 |
#  298 | 0.008037    51.34 |
#  299 | 0.008036    51.34 |
#  300 | 0.008036    51.34 |
#  301 | 0.008035    51.33 |
#  302 | 0.008035    51.33 |
#  303 | 0.008033    51.32 |
#  304 | 0.008033    51.32 |
#  305 | 0.008032    51.31 |
#  306 | 0.008029    51.30 |
#  307 | 0.008027    51.28 |
#  308 | 0.008026    51.28 |
#  309 | 0.008027    51.28 |
#  310 | 0.008027    51.28 |
#  311 | 0.008027    51.28 |
#  312 | 0.008027    51.28 |
#  313 | 0.008026    51.27 |
#  314 | 0.008026    51.27 |
#  315 | 0.008024    51.26 |
#  316 | 0.008024    51.26 |
#  317 | 0.008023    51.26 |
#  318 | 0.008024    51.26 |
#  319 | 0.008024    51.26 |
#  320 | 0.008023    51.26 |
#  321 | 0.008023    51.26 |
#  322 | 0.008022    51.25 |
#  323 | 0.008021    51.25 |
#  324 |  0.00802    51.24 |
#  325 | 0.008019    51.23 |
#  326 |  0.00802    51.24 |
#  327 | 0.008018    51.22 |
#  328 | 0.008019    51.23 |
#  329 | 0.008019    51.23 |
#  330 | 0.008019    51.23 |
#  331 | 0.008019    51.23 |
#  332 | 0.008019    51.23 |
#  333 | 0.008018    51.23 |
#  334 | 0.008018    51.22 |
#  335 | 0.008018    51.23 |
#  336 | 0.008018    51.23 |
#  337 | 0.008018    51.23 |
#  338 | 0.008015    51.21 |
#  339 | 0.008016    51.21 |
#  340 | 0.008015    51.21 |
#  341 | 0.008016    51.21 |
#  342 | 0.008016    51.21 |
#  343 | 0.008015    51.21 |
#  344 | 0.008014    51.20 |
#  345 | 0.008011    51.18 |
#  346 | 0.008011    51.18 |
#  347 | 0.008012    51.18 |
#  348 | 0.008012    51.19 |
#  349 | 0.008012    51.18 |
#  350 | 0.008012    51.19 |
#  351 | 0.008012    51.18 |
#  352 |  0.00801    51.17 |
#  353 | 0.008009    51.17 |
#  354 | 0.008009    51.17 |
#  355 | 0.008009    51.17 |
#  356 | 0.008009    51.17 |
#  357 | 0.008009    51.17 |
#  358 | 0.008009    51.16 |
#  359 | 0.008008    51.16 |
#  360 | 0.008007    51.15 |
#  361 | 0.008006    51.15 |
#  362 | 0.008005    51.14 |
#  363 | 0.008005    51.14 |
#  364 | 0.008006    51.15 |
#  365 | 0.008006    51.15 |
#  366 | 0.008003    51.13 |
#  367 | 0.008004    51.14 |
#  368 | 0.008006    51.15 |
#  369 | 0.008007    51.16 |
#  370 | 0.008007    51.16 |
#  371 | 0.008008    51.16 |
#  372 | 0.008009    51.16 |
#  373 | 0.008008    51.16 |
#  374 | 0.008009    51.17 |
#  375 | 0.008009    51.17 |
#  376 |  0.00801    51.18 |
#  377 |  0.00801    51.18 |
#  378 | 0.008011    51.18 |
#  379 |  0.00801    51.17 |
#  380 | 0.008011    51.18 |
#  381 |  0.00801    51.17 |
#  382 | 0.008011    51.18 |
#  383 | 0.008011    51.18 |
#  384 | 0.008011    51.18 |
#  385 | 0.008011    51.18 |
#  386 | 0.008011    51.18 |
#  387 |  0.00801    51.18 |
#  388 | 0.008009    51.16 |
#  389 |  0.00801    51.17 |
#  390 |  0.00801    51.17 |
#  391 | 0.008009    51.17 |
#  392 | 0.008008    51.16 |
#  393 | 0.008009    51.17 |
#  394 |  0.00801    51.17 |
#  395 | 0.008011    51.18 |
#  396 | 0.008011    51.18 |
#  397 |  0.00801    51.17 |
#  398 | 0.008011    51.18 |
#  399 |  0.00801    51.17 |
#  400 | 0.008012    51.18 |
#  401 | 0.008011    51.18 |
#  402 | 0.008011    51.18 |
#  403 |  0.00801    51.17 |
#  404 |  0.00801    51.17 |
#  405 | 0.008009    51.17 |
#  406 | 0.008009    51.17 |
#  407 |  0.00801    51.17 |
#  408 | 0.008008    51.16 |
#  409 | 0.008008    51.16 |
#  410 | 0.008008    51.16 |
#  411 | 0.008008    51.16 |
#  412 | 0.008008    51.16 |
#  413 | 0.008008    51.16 |
#  414 | 0.008008    51.16 |
#  415 | 0.008007    51.15 |
#  416 | 0.008007    51.15 |
#  417 | 0.008006    51.15 |
#  418 | 0.008006    51.15 |
#  419 | 0.008007    51.15 |
#  420 | 0.008008    51.16 |
#  421 | 0.008008    51.16 |
#  422 | 0.008008    51.16 |
#  423 | 0.008008    51.16 |
#  424 | 0.008008    51.16 |
#  425 | 0.008007    51.15 |
#  426 | 0.008005    51.14 |
#  427 | 0.008005    51.14 |
#  428 | 0.008004    51.14 |
#  429 | 0.008004    51.14 |
#  430 | 0.008004    51.13 |
#  431 | 0.008004    51.13 |
#  432 | 0.008003    51.13 |
#  433 | 0.008003    51.13 |
#  434 | 0.008002    51.12 |
#  435 | 0.008002    51.12 |
#  436 | 0.008001    51.12 |
#  437 | 0.008003    51.13 |
#  438 | 0.008003    51.13 |
#  439 | 0.008004    51.14 |
#  440 | 0.008002    51.13 |
#  441 | 0.008001    51.12 |
#  442 | 0.008001    51.11 |
#  443 | 0.008001    51.12 |
#  444 | 0.008002    51.12 |
#  445 | 0.008001    51.11 |
#  446 | 0.008001    51.12 |
#  447 | 0.008001    51.12 |
#  448 | 0.008001    51.12 |
#  449 | 0.008001    51.12 |
#  450 | 0.008001    51.12 |
#  451 | 0.008001    51.12 |
#  452 | 0.008001    51.12 |
#  453 | 0.008001    51.12 |
#  454 | 0.008002    51.12 |
#  455 | 0.008002    51.13 |
#  456 | 0.008002    51.13 |
#  457 | 0.008002    51.13 |
#  458 | 0.008003    51.13 |
#  459 | 0.008004    51.13 |
#  460 | 0.008004    51.13 |
#  461 | 0.008003    51.13 |
#  462 | 0.008003    51.13 |
#  463 | 0.008003    51.13 |
#  464 | 0.008002    51.12 |
#  465 | 0.008002    51.12 |
#  466 | 0.008001    51.12 |
#  467 | 0.008002    51.12 |
#  468 | 0.008002    51.12 |
#  469 | 0.008001    51.12 |
#  470 |    0.008    51.11 |
#  471 |    0.008    51.11 |
#  472 | 0.007999    51.10 |
#  473 | 0.007999    51.10 |
#  474 | 0.007999    51.10 |
#  475 | 0.007998    51.10 |
#  476 | 0.007998    51.10 |
#  477 | 0.007999    51.10 |
#  478 | 0.007999    51.10 |
#  479 | 0.007998    51.10 |
#  480 | 0.007998    51.10 |
#  481 | 0.007998    51.10 |
#  482 | 0.007998    51.10 |
#  483 | 0.007999    51.10 |
#  484 | 0.007999    51.10 |
#  485 | 0.007999    51.10 |
#  486 | 0.007999    51.10 |
#  487 | 0.007999    51.10 |
#  488 | 0.007998    51.10 |
#  489 | 0.007999    51.10 |
#  490 | 0.007998    51.10 |
#  491 | 0.007998    51.10 |
#  492 | 0.007998    51.09 |
#  493 | 0.007998    51.10 |
#  494 | 0.007997    51.09 |
#  495 | 0.007996    51.08 |
#  496 | 0.007996    51.08 |
#  497 | 0.007996    51.08 |
#  498 | 0.007996    51.08 |
#  499 | 0.007995    51.08 |
#  500 | 0.007995    51.08 |
# Call:
#  randomForest(formula = ATAC_val ~ ., data = sum_control_ATAC_bin_rm,      ntree = 500, do.trace = T)
#                Type of random forest: regression
#                      Number of trees: 500
# No. of variables tried at each split: 223
#
#           Mean of squared residuals: 0.007995095
#                     % Var explained: 48.92

# %%
head(fit$mse)
# Out:
# Error in head(fit$mse): object 'fit' not found
# Traceback:
#
# 1. head(fit$mse)

# %%
head(fit$mse)

#fit$confusion # using all fitted trees

tree_n <- seq(1, 500, 1)

#fit$mse[,1]

ggplot(data = NULL, aes(x = tree_n, y = fit$mse)) + 
  geom_line() + 
  xlab("Tree number") + 
  ylab("Estimated OOB error rate")


pd <- fit$mse %>% tbl_df() %>% mutate(x = row_number())
#pd %>% arrange(OOB)
# Out:
# [1] 0.01644655 0.01558686 0.01473669 0.01412525 0.01349496 0.01294519
# Warning message:
# “`tbl_df()` was deprecated in dplyr 1.0.0.
# Please use `tibble::as_tibble()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# plot without title

# %%
cross_validation <- function(dataset, mtry=NA, k=10){

  if(is.na(mtry)) {
    mtry = floor(sqrt(ncol(dataset)))
  }

  cat(paste(Sys.time(), "Doing mtry:", mtry, "k:", k, "\n"))
  flush.console()

  cvfolds <- cut(seq_len(nrow(dataset)), breaks = k, labels = F)
  cvfolds <- sample(cvfolds)
  
  observed  <- dataset$ATAC_val
  predicted <- observed
  
  for (i in 1:k){
    rows      <- which(cvfolds==i)
    testdata  <- dataset[rows,]
    testdata  <- testdata %>% select(-ATAC_val)
    traindata <- dataset[-rows,]
    
    fit <-  randomForest(y = traindata$ATAC_val,
                         x = traindata %>% select(-ATAC_val),
                     ntree = 700,
                      mtry = mtry,
                  do.trace = F)
    
    tmp       <- predict(fit, newdata = testdata, type="response")
    predicted[rows] <- tmp
  }
  
  mean(observed)
  se    <- (observed-predicted)^2
  mse   <- mean(se)
  (rmse <- sqrt(mse))
  flush.console()
  return(rmse)
}

set.seed(0)
#cross_validation(dataset = sum_control_ATAC_bin_rm, k = 10)

# %%
pd <- tibble(raw=c(0.1, 0.5, 1, 2, 4, 8)) %>%
  mutate(mtry = floor(raw*sqrt(ncol(sum_control_ATAC_bin_rm)))) %>%
  mutate(rmse = NA)

pd


for (i in 1:nrow(pd)){
  set.seed(0)
  pd$rmse[i] = cross_validation(dataset = sum_control_ATAC_bin_rm, mtry = pd$mtry[i], k = 10)
}

knitr::kable(pd)

ggplot(pd, aes(x = mtry, y = rmse)) +
  geom_point() + 
  geom_line() + 
  xlab("m value") + 
  ylab("CV rmse")
# Out:
#   raw mtry rmse
# 1 0.1   2  NA
# 2 0.5  12  NA
# 3 1.0  25  NA
# 4 2.0  51  NA
# 5 4.0 103  NA
# 6 8.0 207  NA
# 2021-09-28 08:50:22 Doing mtry: 2 k: 10
# 2021-09-28 08:58:23 Doing mtry: 12 k: 10
# 2021-09-28 09:19:50 Doing mtry: 25 k: 10
# 2021-09-28 09:58:08 Doing mtry: 51 k: 10
# 2021-09-28 11:09:22 Doing mtry: 103 k: 10
# 2021-09-28 13:24:55 Doing mtry: 207 k: 10
# | raw| mtry|      rmse|
# |---:|----:|---------:|
# | 0.1|    2| 0.0927826|
# | 0.5|   12| 0.0905271|
# | 1.0|   25| 0.0900556|
# | 2.0|   51| 0.0897574|
# | 4.0|  103| 0.0895742|
# | 8.0|  207| 0.0894631|
# plot without title

# %%
set.seed(0)

(fit = randomForest(ATAC_val~., data = sum_control_ATAC_bin_rm, ntree = 700, do.trace = T, mtry = 207))
# Out:
#      |      Out-of-bag   |
# Tree |      MSE  %Var(y) |
#    1 |  0.01693   108.16 |
#    2 |   0.0165   105.43 |
#    3 |  0.01532    97.89 |
#    4 |  0.01434    91.62 |
#    5 |  0.01354    86.52 |
#    6 |  0.01274    81.36 |
#    7 |  0.01213    77.52 |
#    8 |  0.01163    74.33 |
#    9 |  0.01128    72.09 |
#   10 |  0.01088    69.52 |
#   11 |  0.01061    67.81 |
#   12 |  0.01039    66.36 |
#   13 |   0.0102    65.18 |
#   14 |  0.01003    64.05 |
#   15 | 0.009881    63.13 |
#   16 | 0.009719    62.09 |
#   17 | 0.009593    61.28 |
#   18 | 0.009487    60.61 |
#   19 | 0.009385    59.96 |
#   20 | 0.009307    59.46 |
#   21 | 0.009234    58.99 |
#   22 | 0.009197    58.76 |
#   23 | 0.009127    58.31 |
#   24 | 0.009083    58.03 |
#   25 | 0.009049    57.81 |
#   26 | 0.009011    57.57 |
#   27 | 0.008964    57.27 |
#   28 | 0.008936    57.09 |
#   29 | 0.008899    56.85 |
#   30 | 0.008881    56.74 |
#   31 | 0.008827    56.39 |
#   32 | 0.008798    56.21 |
#   33 | 0.008771    56.04 |
#   34 | 0.008755    55.93 |
#   35 | 0.008738    55.82 |
#   36 | 0.008704    55.61 |
#   37 | 0.008688    55.50 |
#   38 | 0.008677    55.43 |
#   39 | 0.008658    55.32 |
#   40 | 0.008635    55.17 |
#   41 |  0.00862    55.07 |
#   42 | 0.008605    54.98 |
#   43 | 0.008587    54.86 |
#   44 | 0.008562    54.70 |
#   45 |  0.00855    54.62 |
#   46 | 0.008531    54.50 |
#   47 | 0.008533    54.52 |
#   48 | 0.008518    54.42 |
#   49 | 0.008509    54.36 |
#   50 | 0.008492    54.25 |
#   51 | 0.008477    54.16 |
#   52 | 0.008463    54.06 |
#   53 |  0.00845    53.99 |
#   54 | 0.008447    53.97 |
#   55 | 0.008433    53.87 |
#   56 | 0.008419    53.79 |
#   57 | 0.008411    53.73 |
#   58 | 0.008405    53.70 |
#   59 | 0.008389    53.59 |
#   60 | 0.008376    53.51 |
#   61 | 0.008372    53.48 |
#   62 | 0.008364    53.44 |
#   63 |  0.00836    53.41 |
#   64 |  0.00835    53.35 |
#   65 | 0.008352    53.36 |
#   66 |  0.00834    53.28 |
#   67 | 0.008335    53.25 |
#   68 | 0.008327    53.20 |
#   69 | 0.008318    53.14 |
#   70 | 0.008315    53.12 |
#   71 | 0.008314    53.11 |
#   72 |  0.00831    53.09 |
#   73 | 0.008295    52.99 |
#   74 | 0.008289    52.96 |
#   75 | 0.008286    52.93 |
#   76 | 0.008282    52.91 |
#   77 | 0.008277    52.88 |
#   78 | 0.008281    52.90 |
#   79 | 0.008274    52.86 |
#   80 | 0.008264    52.80 |
#   81 | 0.008269    52.83 |
#   82 | 0.008267    52.81 |
#   83 | 0.008258    52.76 |
#   84 | 0.008251    52.71 |
#   85 | 0.008245    52.67 |
#   86 | 0.008244    52.67 |
#   87 |  0.00824    52.64 |
#   88 | 0.008234    52.61 |
#   89 | 0.008229    52.57 |
#   90 | 0.008224    52.54 |
#   91 | 0.008221    52.52 |
#   92 |  0.00822    52.51 |
#   93 | 0.008217    52.49 |
#   94 | 0.008216    52.49 |
#   95 | 0.008216    52.49 |
#   96 | 0.008209    52.45 |
#   97 | 0.008205    52.42 |
#   98 | 0.008205    52.42 |
#   99 | 0.008204    52.41 |
#  100 | 0.008201    52.39 |
#  101 |   0.0082    52.39 |
#  102 | 0.008201    52.39 |
#  103 |   0.0082    52.39 |
#  104 | 0.008196    52.36 |
#  105 | 0.008191    52.33 |
#  106 | 0.008192    52.34 |
#  107 | 0.008186    52.30 |
#  108 | 0.008181    52.26 |
#  109 | 0.008179    52.25 |
#  110 | 0.008174    52.22 |
#  111 |  0.00817    52.19 |
#  112 | 0.008164    52.16 |
#  113 | 0.008164    52.16 |
#  114 | 0.008156    52.11 |
#  115 | 0.008157    52.11 |
#  116 | 0.008156    52.11 |
#  117 | 0.008151    52.07 |
#  118 | 0.008147    52.05 |
#  119 | 0.008148    52.05 |
#  120 | 0.008147    52.05 |
#  121 | 0.008144    52.03 |
#  122 | 0.008141    52.01 |
#  123 | 0.008141    52.01 |
#  124 | 0.008136    51.98 |
#  125 | 0.008137    51.99 |
#  126 | 0.008137    51.98 |
#  127 | 0.008135    51.97 |
#  128 |  0.00813    51.94 |
#  129 | 0.008129    51.93 |
#  130 | 0.008127    51.92 |
#  131 | 0.008124    51.90 |
#  132 | 0.008122    51.89 |
#  133 | 0.008119    51.87 |
#  134 | 0.008115    51.84 |
#  135 | 0.008115    51.84 |
#  136 | 0.008113    51.83 |
#  137 |  0.00811    51.81 |
#  138 | 0.008108    51.80 |
#  139 | 0.008108    51.80 |
#  140 |  0.00811    51.81 |
#  141 | 0.008108    51.80 |
#  142 | 0.008107    51.79 |
#  143 |   0.0081    51.75 |
#  144 | 0.008101    51.76 |
#  145 | 0.008101    51.76 |
#  146 |   0.0081    51.75 |
#  147 | 0.008098    51.73 |
#  148 | 0.008093    51.70 |
#  149 | 0.008088    51.67 |
#  150 | 0.008084    51.65 |
#  151 | 0.008085    51.65 |
#  152 | 0.008086    51.66 |
#  153 | 0.008086    51.66 |
#  154 | 0.008082    51.64 |
#  155 | 0.008081    51.63 |
#  156 | 0.008081    51.63 |
#  157 | 0.008081    51.62 |
#  158 | 0.008081    51.63 |
#  159 | 0.008078    51.61 |
#  160 | 0.008081    51.62 |
#  161 |  0.00808    51.62 |
#  162 | 0.008078    51.61 |
#  163 | 0.008079    51.62 |
#  164 | 0.008076    51.59 |
#  165 | 0.008071    51.56 |
#  166 | 0.008071    51.57 |
#  167 | 0.008073    51.57 |
#  168 | 0.008071    51.56 |
#  169 | 0.008066    51.53 |
#  170 | 0.008065    51.53 |
#  171 | 0.008062    51.51 |
#  172 | 0.008062    51.50 |
#  173 | 0.008064    51.52 |
#  174 | 0.008062    51.50 |
#  175 | 0.008062    51.51 |
#  176 | 0.008061    51.50 |
#  177 | 0.008062    51.51 |
#  178 |  0.00806    51.50 |
#  179 | 0.008061    51.50 |
#  180 | 0.008062    51.50 |
#  181 | 0.008062    51.50 |
#  182 | 0.008061    51.50 |
#  183 | 0.008061    51.50 |
#  184 | 0.008061    51.50 |
#  185 |  0.00806    51.49 |
#  186 | 0.008062    51.50 |
#  187 | 0.008063    51.51 |
#  188 | 0.008063    51.51 |
#  189 | 0.008062    51.50 |
#  190 | 0.008061    51.50 |
#  191 | 0.008062    51.50 |
#  192 | 0.008062    51.51 |
#  193 | 0.008063    51.51 |
#  194 | 0.008062    51.51 |
#  195 | 0.008062    51.50 |
#  196 | 0.008062    51.50 |
#  197 | 0.008058    51.48 |
#  198 | 0.008057    51.47 |
#  199 | 0.008055    51.46 |
#  200 | 0.008055    51.46 |
#  201 | 0.008058    51.48 |
#  202 | 0.008057    51.47 |
#  203 | 0.008057    51.47 |
#  204 | 0.008055    51.46 |
#  205 | 0.008055    51.46 |
#  206 | 0.008054    51.45 |
#  207 | 0.008055    51.46 |
#  208 | 0.008055    51.46 |
#  209 | 0.008057    51.47 |
#  210 | 0.008059    51.48 |
#  211 | 0.008059    51.48 |
#  212 | 0.008057    51.48 |
#  213 | 0.008057    51.47 |
#  214 | 0.008058    51.48 |
#  215 | 0.008056    51.47 |
#  216 | 0.008054    51.46 |
#  217 | 0.008055    51.46 |
#  218 | 0.008053    51.45 |
#  219 | 0.008053    51.45 |
#  220 | 0.008052    51.44 |
#  221 | 0.008052    51.44 |
#  222 | 0.008054    51.45 |
#  223 | 0.008054    51.45 |
#  224 | 0.008053    51.45 |
#  225 | 0.008053    51.45 |
#  226 | 0.008052    51.44 |
#  227 | 0.008054    51.45 |
#  228 | 0.008052    51.44 |
#  229 | 0.008051    51.44 |
#  230 | 0.008053    51.45 |
#  231 | 0.008053    51.44 |
#  232 | 0.008049    51.42 |
#  233 | 0.008048    51.42 |
#  234 | 0.008045    51.39 |
#  235 | 0.008046    51.40 |
#  236 | 0.008046    51.41 |
#  237 | 0.008047    51.41 |
#  238 | 0.008048    51.41 |
#  239 | 0.008049    51.42 |
#  240 | 0.008049    51.42 |
#  241 | 0.008049    51.42 |
#  242 | 0.008049    51.42 |
#  243 |  0.00805    51.43 |
#  244 |  0.00805    51.43 |
#  245 | 0.008049    51.43 |
#  246 |  0.00805    51.43 |
#  247 |  0.00805    51.43 |
#  248 | 0.008052    51.44 |
#  249 | 0.008054    51.45 |
#  250 | 0.008051    51.44 |
#  251 |  0.00805    51.43 |
#  252 |  0.00805    51.43 |
#  253 |  0.00805    51.43 |
#  254 | 0.008049    51.42 |
#  255 | 0.008049    51.42 |
#  256 | 0.008048    51.42 |
#  257 | 0.008048    51.41 |
#  258 | 0.008046    51.40 |
#  259 | 0.008046    51.40 |
#  260 | 0.008046    51.40 |
#  261 | 0.008046    51.41 |
#  262 | 0.008045    51.40 |
#  263 | 0.008044    51.39 |
#  264 | 0.008043    51.38 |
#  265 |  0.00804    51.36 |
#  266 |  0.00804    51.37 |
#  267 |  0.00804    51.37 |
#  268 | 0.008041    51.37 |
#  269 | 0.008041    51.37 |
#  270 | 0.008038    51.36 |
#  271 | 0.008038    51.35 |
#  272 | 0.008039    51.36 |
#  273 | 0.008038    51.35 |
#  274 | 0.008038    51.35 |
#  275 | 0.008036    51.34 |
#  276 | 0.008036    51.34 |
#  277 | 0.008037    51.34 |
#  278 | 0.008037    51.35 |
#  279 | 0.008038    51.35 |
#  280 | 0.008039    51.36 |
#  281 | 0.008038    51.35 |
#  282 | 0.008039    51.36 |
#  283 | 0.008038    51.35 |
#  284 | 0.008037    51.35 |
#  285 | 0.008037    51.34 |
#  286 | 0.008036    51.34 |
#  287 | 0.008035    51.33 |
#  288 | 0.008035    51.33 |
#  289 | 0.008036    51.34 |
#  290 | 0.008036    51.34 |
#  291 | 0.008037    51.35 |
#  292 | 0.008038    51.35 |
#  293 | 0.008037    51.35 |
#  294 | 0.008038    51.35 |
#  295 | 0.008037    51.34 |
#  296 | 0.008036    51.34 |
#  297 | 0.008037    51.34 |
#  298 | 0.008036    51.34 |
#  299 | 0.008035    51.34 |
#  300 | 0.008036    51.34 |
#  301 | 0.008035    51.34 |
#  302 | 0.008034    51.33 |
#  303 | 0.008032    51.31 |
#  304 | 0.008032    51.31 |
#  305 | 0.008031    51.31 |
#  306 |  0.00803    51.30 |
#  307 |  0.00803    51.30 |
#  308 | 0.008029    51.30 |
#  309 | 0.008027    51.28 |
#  310 | 0.008026    51.27 |
#  311 | 0.008026    51.28 |
#  312 | 0.008027    51.28 |
#  313 | 0.008028    51.29 |
#  314 | 0.008027    51.28 |
#  315 | 0.008028    51.29 |
#  316 | 0.008027    51.28 |
#  317 | 0.008025    51.27 |
#  318 | 0.008026    51.28 |
#  319 | 0.008026    51.28 |
#  320 | 0.008026    51.28 |
#  321 | 0.008026    51.27 |
#  322 | 0.008024    51.26 |
#  323 | 0.008024    51.27 |
#  324 | 0.008025    51.27 |
#  325 | 0.008025    51.27 |
#  326 | 0.008026    51.27 |
#  327 | 0.008027    51.28 |
#  328 | 0.008028    51.29 |
#  329 | 0.008027    51.28 |
#  330 | 0.008027    51.28 |
#  331 | 0.008028    51.29 |
#  332 | 0.008028    51.29 |
#  333 | 0.008028    51.29 |
#  334 | 0.008028    51.29 |
#  335 | 0.008027    51.28 |
#  336 | 0.008027    51.28 |
#  337 | 0.008026    51.27 |
#  338 | 0.008027    51.28 |
#  339 | 0.008027    51.28 |
#  340 | 0.008025    51.27 |
#  341 | 0.008025    51.27 |
#  342 | 0.008025    51.27 |
#  343 | 0.008024    51.26 |
#  344 | 0.008024    51.27 |
#  345 | 0.008025    51.27 |
#  346 | 0.008024    51.26 |
#  347 | 0.008028    51.29 |
#  348 | 0.008028    51.29 |
#  349 | 0.008027    51.28 |
#  350 | 0.008027    51.28 |
#  351 | 0.008027    51.28 |
#  352 | 0.008025    51.27 |
#  353 | 0.008025    51.27 |
#  354 | 0.008026    51.27 |
#  355 | 0.008026    51.27 |
#  356 | 0.008026    51.28 |
#  357 | 0.008026    51.28 |
#  358 | 0.008027    51.28 |
#  359 | 0.008027    51.28 |
#  360 | 0.008027    51.28 |
#  361 | 0.008028    51.29 |
#  362 | 0.008028    51.29 |
#  363 | 0.008028    51.29 |
#  364 | 0.008029    51.29 |
#  365 | 0.008029    51.29 |
#  366 | 0.008029    51.30 |
#  367 |  0.00803    51.30 |
#  368 | 0.008028    51.29 |
#  369 | 0.008028    51.29 |
#  370 | 0.008027    51.28 |
#  371 | 0.008027    51.28 |
#  372 | 0.008027    51.28 |
#  373 | 0.008026    51.28 |
#  374 | 0.008027    51.28 |
#  375 | 0.008026    51.28 |
#  376 | 0.008026    51.28 |
#  377 | 0.008025    51.27 |
#  378 | 0.008024    51.26 |
#  379 | 0.008022    51.25 |
#  380 | 0.008024    51.26 |
#  381 | 0.008024    51.26 |
#  382 | 0.008025    51.27 |
#  383 | 0.008025    51.27 |
#  384 | 0.008025    51.27 |
#  385 | 0.008024    51.26 |
#  386 | 0.008024    51.27 |
#  387 | 0.008025    51.27 |
#  388 | 0.008024    51.26 |
#  389 | 0.008024    51.27 |
#  390 | 0.008024    51.27 |
#  391 | 0.008024    51.27 |
#  392 | 0.008024    51.26 |
#  393 | 0.008024    51.26 |
#  394 | 0.008024    51.26 |
#  395 | 0.008024    51.26 |
#  396 | 0.008024    51.26 |
#  397 | 0.008024    51.26 |
#  398 | 0.008023    51.26 |
#  399 | 0.008023    51.26 |
#  400 | 0.008023    51.25 |
#  401 | 0.008022    51.25 |
#  402 | 0.008021    51.25 |
#  403 | 0.008022    51.25 |
#  404 | 0.008022    51.25 |
#  405 | 0.008023    51.26 |
#  406 | 0.008024    51.26 |
#  407 | 0.008024    51.26 |
#  408 | 0.008022    51.25 |
#  409 | 0.008021    51.25 |
#  410 | 0.008021    51.24 |
#  411 | 0.008021    51.24 |
#  412 | 0.008021    51.24 |
#  413 |  0.00802    51.24 |
#  414 | 0.008021    51.24 |
#  415 | 0.008023    51.25 |
#  416 | 0.008023    51.26 |
#  417 | 0.008022    51.25 |
#  418 | 0.008023    51.25 |
#  419 | 0.008023    51.26 |
#  420 | 0.008024    51.27 |
#  421 | 0.008025    51.27 |
#  422 | 0.008025    51.27 |
#  423 | 0.008025    51.27 |
#  424 | 0.008025    51.27 |
#  425 | 0.008025    51.27 |
#  426 | 0.008025    51.27 |
#  427 | 0.008026    51.28 |
#  428 | 0.008028    51.29 |
#  429 | 0.008027    51.28 |
#  430 | 0.008026    51.27 |
#  431 | 0.008026    51.27 |
#  432 | 0.008025    51.27 |
#  433 | 0.008025    51.27 |
#  434 | 0.008026    51.28 |
#  435 | 0.008026    51.27 |
#  436 | 0.008026    51.27 |
#  437 | 0.008024    51.26 |
#  438 | 0.008024    51.26 |
#  439 | 0.008023    51.26 |
#  440 | 0.008024    51.26 |
#  441 | 0.008022    51.25 |
#  442 | 0.008022    51.25 |
#  443 | 0.008021    51.24 |
#  444 |  0.00802    51.24 |
#  445 | 0.008019    51.23 |
#  446 | 0.008018    51.23 |
#  447 | 0.008018    51.23 |
#  448 | 0.008018    51.23 |
#  449 | 0.008018    51.22 |
#  450 | 0.008018    51.22 |
#  451 | 0.008018    51.22 |
#  452 | 0.008018    51.23 |
#  453 | 0.008018    51.22 |
#  454 | 0.008018    51.22 |
#  455 | 0.008018    51.22 |
#  456 | 0.008017    51.22 |
#  457 | 0.008015    51.21 |
#  458 | 0.008015    51.21 |
#  459 | 0.008015    51.20 |
#  460 | 0.008013    51.19 |
#  461 | 0.008011    51.18 |
#  462 | 0.008012    51.18 |
#  463 | 0.008012    51.18 |
#  464 | 0.008011    51.18 |
#  465 | 0.008012    51.19 |
#  466 | 0.008012    51.18 |
#  467 | 0.008012    51.19 |
#  468 | 0.008012    51.19 |
#  469 | 0.008012    51.19 |
#  470 | 0.008011    51.18 |
#  471 | 0.008011    51.18 |
#  472 | 0.008011    51.18 |
#  473 | 0.008011    51.18 |
#  474 |  0.00801    51.17 |
#  475 | 0.008011    51.18 |
#  476 | 0.008011    51.18 |
#  477 | 0.008011    51.18 |
#  478 |  0.00801    51.18 |
#  479 |  0.00801    51.18 |
#  480 |  0.00801    51.17 |
#  481 |  0.00801    51.17 |
#  482 |  0.00801    51.17 |
#  483 |  0.00801    51.17 |
#  484 |  0.00801    51.17 |
#  485 | 0.008009    51.16 |
#  486 | 0.008008    51.16 |
#  487 | 0.008007    51.16 |
#  488 | 0.008006    51.15 |
#  489 | 0.008005    51.14 |
#  490 | 0.008004    51.14 |
#  491 | 0.008004    51.14 |
#  492 | 0.008004    51.13 |
#  493 | 0.008003    51.13 |
#  494 | 0.008004    51.13 |
#  495 | 0.008003    51.13 |
#  496 | 0.008003    51.13 |
#  497 | 0.008004    51.14 |
#  498 | 0.008005    51.14 |
#  499 | 0.008005    51.14 |
#  500 | 0.008005    51.14 |
#  501 | 0.008006    51.15 |
#  502 | 0.008005    51.14 |
#  503 | 0.008004    51.14 |
#  504 | 0.008004    51.13 |
#  505 | 0.008004    51.14 |
#  506 | 0.008004    51.14 |
#  507 | 0.008004    51.14 |
#  508 | 0.008004    51.13 |
#  509 | 0.008005    51.14 |
#  510 | 0.008004    51.14 |
#  511 | 0.008004    51.14 |
#  512 | 0.008005    51.14 |
#  513 | 0.008005    51.14 |
#  514 | 0.008004    51.14 |
#  515 | 0.008004    51.13 |
#  516 | 0.008004    51.13 |
#  517 | 0.008004    51.14 |
#  518 | 0.008004    51.13 |
#  519 | 0.008003    51.13 |
#  520 | 0.008002    51.12 |
#  521 | 0.008003    51.13 |
#  522 | 0.008002    51.12 |
#  523 | 0.008003    51.13 |
#  524 | 0.008004    51.13 |
#  525 | 0.008003    51.13 |
#  526 | 0.008003    51.13 |
#  527 | 0.008003    51.13 |
#  528 | 0.008003    51.13 |
#  529 | 0.008003    51.13 |
#  530 | 0.008004    51.13 |
#  531 | 0.008004    51.14 |
#  532 | 0.008004    51.13 |
#  533 | 0.008004    51.13 |
#  534 | 0.008004    51.13 |
#  535 | 0.008004    51.14 |
#  536 | 0.008005    51.14 |
#  537 | 0.008005    51.14 |
#  538 | 0.008004    51.14 |
#  539 | 0.008004    51.13 |
#  540 | 0.008003    51.13 |
#  541 | 0.008003    51.13 |
#  542 | 0.008004    51.13 |
#  543 | 0.008003    51.13 |
#  544 | 0.008003    51.13 |
#  545 | 0.008002    51.12 |
#  546 | 0.008002    51.12 |
#  547 | 0.008002    51.12 |
#  548 | 0.008001    51.11 |
#  549 | 0.008001    51.11 |
#  550 |    0.008    51.11 |
#  551 |    0.008    51.11 |
#  552 | 0.007999    51.10 |
#  553 | 0.007999    51.10 |
#  554 | 0.007999    51.10 |
#  555 | 0.007999    51.10 |
#  556 | 0.007998    51.10 |
#  557 | 0.007998    51.10 |
#  558 | 0.007999    51.10 |
#  559 | 0.007999    51.10 |
#  560 | 0.007999    51.10 |
#  561 | 0.007999    51.10 |
#  562 | 0.007997    51.09 |
#  563 | 0.007998    51.10 |
#  564 | 0.007999    51.10 |
#  565 | 0.007998    51.09 |
#  566 | 0.007998    51.10 |
#  567 | 0.007999    51.10 |
#  568 | 0.007998    51.10 |
#  569 | 0.007999    51.10 |
#  570 | 0.007999    51.10 |
#  571 |    0.008    51.11 |
#  572 |    0.008    51.11 |
#  573 |    0.008    51.11 |
#  574 |    0.008    51.11 |
#  575 |    0.008    51.11 |
#  576 | 0.007999    51.10 |
#  577 | 0.007999    51.10 |
#  578 | 0.007998    51.10 |
#  579 | 0.007997    51.09 |
#  580 | 0.007996    51.09 |
#  581 | 0.007996    51.09 |
#  582 | 0.007996    51.09 |
#  583 | 0.007997    51.09 |
#  584 | 0.007996    51.08 |
#  585 | 0.007997    51.09 |
#  586 | 0.007996    51.09 |
#  587 | 0.007996    51.08 |
#  588 | 0.007996    51.08 |
#  589 | 0.007995    51.08 |
#  590 | 0.007995    51.08 |
#  591 | 0.007996    51.08 |
#  592 | 0.007996    51.08 |
#  593 | 0.007997    51.09 |
#  594 | 0.007996    51.08 |
#  595 | 0.007997    51.09 |
#  596 | 0.007997    51.09 |
#  597 | 0.007997    51.09 |
#  598 | 0.007997    51.09 |
#  599 | 0.007997    51.09 |
#  600 | 0.007997    51.09 |
#  601 | 0.007997    51.09 |
#  602 | 0.007997    51.09 |
#  603 | 0.007997    51.09 |
#  604 | 0.007997    51.09 |
#  605 | 0.007996    51.09 |
#  606 | 0.007996    51.09 |
#  607 | 0.007995    51.08 |
#  608 | 0.007996    51.08 |
#  609 | 0.007997    51.09 |
#  610 | 0.007997    51.09 |
#  611 | 0.007996    51.08 |
#  612 | 0.007997    51.09 |
#  613 | 0.007997    51.09 |
#  614 | 0.007998    51.10 |
#  615 | 0.007998    51.09 |
#  616 | 0.007997    51.09 |
#  617 | 0.007997    51.09 |
#  618 | 0.007997    51.09 |
#  619 | 0.007997    51.09 |
#  620 | 0.007997    51.09 |
#  621 | 0.007997    51.09 |
#  622 | 0.007998    51.10 |
#  623 | 0.007998    51.09 |
#  624 | 0.007997    51.09 |
#  625 | 0.007997    51.09 |
#  626 | 0.007996    51.08 |
#  627 | 0.007996    51.08 |
#  628 | 0.007996    51.08 |
#  629 | 0.007995    51.08 |
#  630 | 0.007995    51.08 |
#  631 | 0.007995    51.08 |
#  632 | 0.007995    51.08 |
#  633 | 0.007995    51.08 |
#  634 | 0.007994    51.07 |
#  635 | 0.007995    51.07 |
#  636 | 0.007996    51.08 |
#  637 | 0.007995    51.08 |
#  638 | 0.007995    51.07 |
#  639 | 0.007995    51.07 |
#  640 | 0.007994    51.07 |
#  641 | 0.007994    51.07 |
#  642 | 0.007995    51.07 |
#  643 | 0.007994    51.07 |
#  644 | 0.007994    51.07 |
#  645 | 0.007994    51.07 |
#  646 | 0.007994    51.07 |
#  647 | 0.007995    51.08 |
#  648 | 0.007994    51.07 |
#  649 | 0.007995    51.08 |
#  650 | 0.007995    51.08 |
#  651 | 0.007995    51.08 |
#  652 | 0.007994    51.07 |
#  653 | 0.007994    51.07 |
#  654 | 0.007994    51.07 |
#  655 | 0.007994    51.07 |
#  656 | 0.007994    51.07 |
#  657 | 0.007994    51.07 |
#  658 | 0.007994    51.07 |
#  659 | 0.007994    51.07 |
#  660 | 0.007994    51.07 |
#  661 | 0.007994    51.07 |
#  662 | 0.007994    51.07 |
#  663 | 0.007995    51.08 |
#  664 | 0.007995    51.08 |
#  665 | 0.007995    51.08 |
#  666 | 0.007995    51.08 |
#  667 | 0.007995    51.08 |
#  668 | 0.007994    51.07 |
#  669 | 0.007994    51.07 |
#  670 | 0.007994    51.07 |
#  671 | 0.007994    51.07 |
#  672 | 0.007994    51.07 |
#  673 | 0.007993    51.07 |
#  674 | 0.007993    51.07 |
#  675 | 0.007993    51.07 |
#  676 | 0.007993    51.07 |
#  677 | 0.007994    51.07 |
#  678 | 0.007994    51.07 |
#  679 | 0.007993    51.06 |
#  680 | 0.007993    51.06 |
#  681 | 0.007993    51.07 |
#  682 | 0.007994    51.07 |
#  683 | 0.007994    51.07 |
#  684 | 0.007995    51.08 |
#  685 | 0.007994    51.07 |
#  686 | 0.007994    51.07 |
#  687 | 0.007994    51.07 |
#  688 | 0.007993    51.07 |
#  689 | 0.007993    51.07 |
#  690 | 0.007993    51.07 |
#  691 | 0.007993    51.07 |
#  692 | 0.007993    51.06 |
#  693 | 0.007992    51.06 |
#  694 | 0.007991    51.05 |
#  695 | 0.007991    51.05 |
#  696 | 0.007991    51.05 |
#  697 | 0.007991    51.05 |
#  698 |  0.00799    51.05 |
#  699 |  0.00799    51.05 |
#  700 |  0.00799    51.04 |
# Call:
#  randomForest(formula = ATAC_val ~ ., data = sum_control_ATAC_bin_rm,      ntree = 700, do.trace = T, mtry = 207)
#                Type of random forest: regression
#                      Number of trees: 700
# No. of variables tried at each split: 207
#
#           Mean of squared residuals: 0.007989553
#                     % Var explained: 48.96

# %% [markdown]
# ### Make predictions

# %%
filename = "data/all_samples_normalized.csv"

# %%
cols_predictions = as.data.frame(t(c("sample", "bin", "ATAC_prediction")))

# %%
# Initiate the empty files and add column names


write.table(NULL, file="data/ATAC_predictions_on_all_samples/ATAC_pred_random_forest.csv", 
             append = F, 
             sep=',', 
             row.names=F, 
             col.names=F)

#colnames_pred <- c("sample", "bin", "ATAC_prediction")


write.table(cols_predictions, "data/ATAC_predictions_on_all_samples/ATAC_pred_random_forest.csv", append = F, sep=',', col.names=F, row.names=F)

# %%
f <- function(df1, pos) {

    df1[3:673] <- lapply(df1[3:673], as.numeric)
    
    df <- df1 %>% select(-c("sample", "bin")) %>% as.matrix()
    tmp       <- as.vector(predict(fit, df, type="response"))


    tmp <- tibble(sample = df1$sample, bin = df1$bin, ATAC_prediction = tmp)
    #message(tmp)
    write.table(tmp, "data/ATAC_predictions_on_all_samples/ATAC_pred_random_forest.csv", append = TRUE, sep=',', col.names=F, row.names=F)
   

}

df <- read_delim_chunked(file = filename, 
                 callback = DataFrameCallback$new(f), 
                 chunk_size = 10000, col_names = T,
                 delim = ",", 
                 progress = show_progress())
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   sample = col_character(),
#   bin = col_character()
# )
# See spec(...) for full column specifications.
